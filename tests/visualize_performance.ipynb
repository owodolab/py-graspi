# %% [markdown]
# # Visualize Performance
# ---
# This file visualizes performances of graph construction and descriptor calculation using csv files
#
# You can generate csv file by calling **save_dict_to_csv()** (check graspi_igraph_notebook.ipynb for details)

# %% [markdown]
# ## Single Graph

# %%
import os
cwd = os.getcwd()  
import testing_helper as tst
import importlib
importlib.reload(tst)
print(cwd)  #the last part should be .../py-graspi/tests
# Out:
# /Users/hwi/Develop/ClassSrc/CSE302/py-graspi/tests

# %%
tst.plot_total_execution_and_memory(cwd+"/performance/stats_main_igraph.csv")

# %%
tst.plot_stepwise_execution_and_memory(cwd+"/performance/stats_main_igraph.csv")

# %% [markdown]
# ## Compare two performances

# %%
tst.plot_total_execution_and_memory('./performance/stats_main_igraph.csv', './performance/stats_new_green_method.csv')

# %%
tst.plot_stepwise_execution_and_memory(cwd+"/performance/stats_main_igraph.csv", cwd+"/performance/stats_new_green_method.csv")
