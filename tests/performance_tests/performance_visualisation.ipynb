# %% [markdown]
# # Visualize Performance
#
# This file visualizes performances of graph construction and descriptor calculation using specified csv files that contain filenames of morphologies and the corresponding statistics of graph generation and descriptor computation. It shows the execution time and memory usage comparison for the data in one single given set of performance data (CSV files), as well as performance data for two sets (2 CSV Files). It shows the performance in both histograms and bar charts.

# %% [markdown]
# ## Single Graph
#
# The following cell imports the necessary libraries as well as prints the working directory for confirmation that the notebook is in the correct folder. It should end with '/performance_tests'.

# %%
import os
cwd = os.getcwd()  
import visualization_helper as tst
import importlib
importlib.reload(tst)
print(cwd)  #the last part should be .../py-graspi/tests
# Out:
# /Users/laibahahmed/PycharmProjects/profilingpygraspi/py-graspi/tests/performance_tests

# %% [markdown]
# This line uses the 'plot_total_execution_and_memory' function from the imported 'visualization_helper' module under the alias 'tst' to visualize the total execution time and the peak memory usage for various groups of test files in a single given CSV file. The CSV file path and filename can be changed as necessary, it should lie in the tests/performance_tests/performance_results folder.

# %%
tst.plot_total_execution_and_memory(cwd+"/performance_results/stats_new_2D.csv")

# %% [markdown]
# This line uses the 'plot_stepwise_execution_and_memory' from the imported 'visualization_helper' module under the alias tst to visualize the data this time on bars rather than a histogram format for a different type of visual comparison. It shows the time and memory it took to generate the graphs and compute the descriptors for the various given test files according to the data in the specified CSV file. This can be changed as necessary as well.

# %%
tst.plot_stepwise_execution_and_memory(cwd+"/performance_results/stats_new_2D.csv")

# %% [markdown]
# ## Compare two performances
# This line uses the 'plot_total_execution_and_memory' function from the imported 'visualization_helper' module under the alias 'tst' to visualize the total execution time and the peak memory usage for various groups of test files in a two given CSV file. This allows us to see a comparison of two different sets of performance data. The CSV file paths and filenames can be changed as necessary, they should lie in the tests/performance_tests/performance_results folder.

# %%
tst.plot_total_execution_and_memory('performance_results/stats_new_2D.csv', 'performance_results/stats_prev_igraph.csv')

# %% [markdown]
# This line uses the 'plot_stepwise_execution_and_memory' from the imported 'visualization_helper' module under the alias tst to visualize the data this time on bars rather than a histogram format for a different type of visual comparison. It shows the time and memory it took to generate the graphs and compute the descriptors for the various given test files according to the data in two specified CSV files. This allows us an easier visual comparison of two sets of performance data. This can be changed as necessary as well.

# %%
tst.plot_stepwise_execution_and_memory(cwd+"/performance_results/stats_new_2D.csv", cwd+"/performance_results/stats_prev_igraph.csv")
