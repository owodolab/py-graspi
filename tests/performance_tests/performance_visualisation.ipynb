# %% [markdown]
# # Visualize Performance
# ---
# This file visualizes performances of graph construction and descriptor calculation using csv files
#
# You can generate csv file by calling **save_dict_to_csv()** (check graspi_igraph_notebook.ipynb for details)

# %% [markdown]
# ## Single Graph

# %%
import os
cwd = os.getcwd()  
import visualization_helper as tst
import importlib
importlib.reload(tst)
print(cwd)  #the last part should be .../py-graspi/tests
# Out:
# /Users/laibahahmed/PycharmProjects/profilingpygraspi/py-graspi/tests

# %%
tst.plot_total_execution_and_memory(cwd+"/performance_results/stats_new_2D.csv")

# %%
tst.plot_stepwise_execution_and_memory(cwd+"/performance_results/stats_new_2D.csv")

# %% [markdown]
# ## Compare two performances

# %%
tst.plot_total_execution_and_memory('./performance_results/stats_main_igraph.csv', './performance_results/stats_new_green_method.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 tst.plot_total_execution_and_memory('./performance_results/stats_main_igraph.csv', './performance_results/stats_new_green_method.csv')
#
# File ~/PycharmProjects/profilingpygraspi/py-graspi/tests/visualize_helper.py:38, in plot_total_execution_and_memory(csv_file1, csv_file2)
#      34 def plot_total_execution_and_memory(csv_file1, csv_file2=None):
#      35     """
#      36     Compare (or show) total execution time and peak memory usage from one or two CSV files.
#      37     """
# ---> 38     df1 = pd.read_csv(csv_file1)
#      39     label1 = os.path.basename(csv_file1)
#      41     if csv_file2:
#
# ...

# %%
tst.plot_stepwise_execution_and_memory(cwd+"/performance_results/stats_main_igraph.csv", cwd+"/performance_results/stats_new_green_method.csv")
