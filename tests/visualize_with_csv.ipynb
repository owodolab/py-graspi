# %% [markdown]
# ## Single Graph

# %%
import testing_helper as tst
import importlib
importlib.reload(tst)
# Out:
# <module 'testing_helper' from '/Users/hwi/Develop/ClassSrc/CSE302/py-graspi/tests/testing_helper.py'>

# %%
tst.plot_total_execution_and_memory_compare("./performance/stats_new_green_method.csv")
tst.plot_stepwise_execution_and_memory_compare("./performance/stats_new_green_method.csv")

# %% [markdown]
# ## Graph Comparison

# %%
tst.plot_total_execution_and_memory_compare('performance/stats_main_igraph.csv', 'performance/stats_new_green_method.csv')

# %%
tst.plot_stepwise_execution_and_memory_compare('performance/stats_main_igraph.csv', 'performance/stats_main_modified_igraph.csv')
