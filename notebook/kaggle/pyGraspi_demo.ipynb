# %% [markdown]
# <a href="https://www.kaggle.com/code/pygraspinotebook/pygraspi-demo-ipynb?scriptVersionId=249460837" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Using Py-Graspi
# In this tutorial we will run through the basic steps of installing the Py-Graspi package as well as how one would generate a graph and output it's descriptors. This will be done through step by step functions laid out through cells in this Notebook.
# Click following hyperlink to open Notebook in interactive mode:
#
# [![Binder](https://mybinder.org/badge.svg)](https://mybinder.org/v2/gh/kkevinmartinezz/kaggle_PyGraspi/3d7bf5df17b015612ab1b8261c63d0bbb00a268f?urlpath=lab%2Ftree%2Fpygraspi-test.ipynb)
#
# # Installing package
# First, we will need to install the Py-Graspi package with the following command:

# %%
# !pip install py-graspi==0.2.1.1b0
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fpdf: filename=fpdf-1.7.2-py2.py3-none-any.whl size=40704 sha256=89327e78c165d8e42baa5180ce94ee37caf83f811f396b6708a564cc0276b308
#   Stored in directory: /root/.cache/pip/wheels/f9/95/ba/f418094659025eb9611f17cbcaf2334236bf39a0c3453ea455
# Successfully built fpdf
# ...

# %% [markdown]
# # Imports
# Second, we will need to import some neccessary items.
#
# The first import "Image" is only included in this Notebook to show a visualization of the already given example file.
#
# The next two imports are necessary and included from the py-graspi package and do the following:
#
# src.graph will be utilized to generate the graph for the file.
#
# src.descriptors will be utilized to generate the descriptors of the graph returned by graph.
#
# *The following wget functions are only included to get test input files from an already existing GitHub repo.

# %%
#import following to be able to output image
from PIL import Image
#import py_graspi library
import py_graspi

# %%
# !wget -O  test_file.txt https://raw.githubusercontent.com/owodolab/py-graspi/refs/heads/dev/data/data/data_0.514_2.4_000220.txt
# !wget -O testImage_file.png https://github.com/owodolab/py-graspi/blob/dev/data/images/data_0.514_2.4_000220.png?raw=true
# Out:
# --2025-07-08 17:43:22--  https://raw.githubusercontent.com/owodolab/py-graspi/refs/heads/dev/data/data/data_0.514_2.4_000220.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 131080 (128K) [text/plain]
# Saving to: ‘test_file.txt’
#
# test_file.txt       100%[===================>] 128.01K  --.-KB/s    in 0.009s
#
# 2025-07-08 17:43:22 (14.3 MB/s) - ‘test_file.txt’ saved [131080/131080]
#
# --2025-07-08 17:43:22--  https://github.com/owodolab/py-graspi/blob/dev/data/images/data_0.514_2.4_000220.png?raw=true
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
img = Image.open("testImage_file.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=1 size=514x130>

# %% [markdown]
# # Functions and Generation
# The generateGraphAdj() function from igraph_testing is used to generate a graph.
#
# The descriptors() function from decriptors is used to generate a dictionary of ut's descriptors.

# %%
#This function will create a graph based on any given txt file input
graph_data= py_graspi.generateGraphAdj("test_file.txt")

# %%
#This function will create a tuple holding in the name and value of all descriptors
dict = py_graspi.compute_descriptors(graph_data, "test_file.txt")

# %% [markdown]
# # Outputting Descriptors
# The next couple of lines are basic opening and writing a dictionaries contents to a file.

# %%
outputFile = "example_descriptors.txt"
py_graspi.descriptorsToTxt(dict,outputFile)

# %%
#Output txt file, if error occurs this means txt file was not properly created
with open(outputFile, 'r') as file:
    content = file.read()
    print(content)
# Out:
# STAT_n 65536.0
# STAT_e 2685.0
# STAT_n_D 30979.0
# STAT_n_A 34557.0
# STAT_CC_D 8.0
# STAT_CC_A 3.0
# STAT_CC_D_An 1.0
# STAT_CC_A_Ca 1.0
# ABS_wf_D 0.289437642232258
# ABS_f_D 0.4727020263671875
# DISS_f10_D 0.6420155589270151
# DISS_wf10_D 0.33095443578530515
# CT_f_e_conn 0.42048417132216015
# CT_f_conn_D_An 0.5464992414216082
# CT_f_conn_A_Ca 0.9760395867696848
# CT_e_conn 1129.0
# CT_e_D_An 1285.0
# CT_e_A_Ca 2557.0
# CT_n_D_adj_An 512.0
# CT_n_A_adj_Ca 512.0
# CT_f_D_tort1 0.6683402244536326
# CT_f_A_tort1 0.5629576921936612
