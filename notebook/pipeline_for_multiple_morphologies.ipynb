# %% [markdown]
# This notebook automates the descriptor generation pipeline using the 'py_graspi' package for multiple morphologies. First, it verifies that the 'py_graspi' package is installed, then computes the graph data for each valid morphology '.txt' file in a target directory, and finally prints the corresponding descriptor values.

# %% [markdown]
# The following cell checks if the py_graspi package is installed or not. If it is, it will print information about the package.

# %%
# !pip show py_graspi
# Out:
# Name: py_graspi
# Version: 0.2.1.2
# Summary: Graph-based descriptor for microstructure featurization
# Home-page: https://github.com/owodolab/py-graspi
# Author: Olga Wodo
# Author-email: olgawodo@buffalo.edu
# License: BSD 3-Clause License
# Location: /Users/laibahahmed/PycharmProjects/profilingpygraspi/.venv/lib/python3.11/site-packages
# Requires: contourpy, cycler, fonttools, fpdf, igraph, kiwisolver, matplotlib, numpy, packaging, pillow, psutil, pyparsing, python-dateutil, six, texttable
# Required-by:

# %% [markdown]
# This cell imports necessary modules to set up the environment. Then, it adds the 'src' directory to enable imports from it. It also imports the appropriate graph construction and descriptor generation modules from the py_graspi package.

# %%
import sys
import os
import glob
sys.path.append(os.path.abspath('../src/'))

from py_graspi import graph as ig
from py_graspi import descriptors as ds

# %% [markdown]
# The following cell takes in a target directory, this can be adjusted as needed by changing the target_directory variable. Then, it scans the chosen directory for morphology files that are in .txt form and follow the appropriate naming conventions with 3 underscores in the filename.

# %%
target_directory = '../data/2phase/2D-morphologies/data'
test_files = [os.path.splitext(file)[0] for file in os.listdir(target_directory)
              if file.endswith('.txt') and os.path.splitext(file)[0].count("_") == 3]

# %% [markdown]
# For each of these files, the graphs data is calculated, descriptors are generated, and then the values are printed out.

# %%
for test in test_files:
    filename = os.path.join(target_directory, test + ".txt")
    print("Descriptors for morphology: " + filename)
    graph_data = ig.generateGraph(filename)
    desc = ds.compute_descriptors(graph_data, filename)
    ds.printDescriptors(desc)
    print("\n")
# Out:
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.528_3.8_000160.txt
# STAT_n 40501
# STAT_e 3640
# STAT_n_D 19268
# STAT_n_A 21233
# STAT_CC_D 26
# STAT_CC_A 6
# STAT_CC_D_An 10
# STAT_CC_A_Ca 4
# ABS_wf_D 0.30139117441530305
# ABS_f_D 0.47574133972000693
# DISS_f10_D 0.9906580859456093
# DISS_wf10_D 0.5947153829336029
# CT_f_e_conn 0.2986263736263736
# CT_f_conn_D_An 0.3195453601826863
# CT_f_conn_A_Ca 0.9798426976875618
# CT_e_conn 1087
# CT_e_D_An 1150
# CT_e_A_Ca 3611
# CT_n_D_adj_An 206
# CT_n_A_adj_Ca 195
# CT_f_D_tort1 0.5224947214552542
# CT_f_A_tort1 0.15294400384522952
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.5_2.2_001900.txt
# STAT_n 65536
# STAT_e 1612
# STAT_n_D 32713
# STAT_n_A 32823
# STAT_CC_D 3
# STAT_CC_A 1
# STAT_CC_D_An 1
# STAT_CC_A_Ca 1
# ABS_wf_D 0.31148777712164943
# ABS_f_D 0.4991607666015625
# DISS_f10_D 0.4223397426099716
# DISS_wf10_D 0.21415371456093757
# CT_f_e_conn 0.78287841191067
# CT_f_conn_D_An 0.8702656436279155
# CT_f_conn_A_Ca 1.0
# CT_e_conn 1262
# CT_e_D_An 1262
# CT_e_A_Ca 1616
# CT_n_D_adj_An 512
# CT_n_A_adj_Ca 512
# CT_f_D_tort1 0.9691594365801398
# CT_f_A_tort1 0.7340279681930354
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.586_3.2_003200.txt
# STAT_n 65536
# STAT_e 2248
# STAT_n_D 26878
# STAT_n_A 38658
# STAT_CC_D 9
# STAT_CC_A 1
# STAT_CC_D_An 1
# STAT_CC_A_Ca 1
# ABS_wf_D 0.254932737591933
# ABS_f_D 0.410125732421875
# DISS_f10_D 0.5793213780787261
# DISS_wf10_D 0.30767007116675466
# CT_f_e_conn 0.32695729537366547
# CT_f_conn_D_An 0.40244809881687627
# CT_f_conn_A_Ca 1.0
# CT_e_conn 735
# CT_e_D_An 735
# CT_e_A_Ca 2278
# CT_n_D_adj_An 512
# CT_n_A_adj_Ca 512
# CT_f_D_tort1 1.0
# CT_f_A_tort1 0.5214185938227534
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.558_3.4_000040.txt
# STAT_n 65536
# STAT_e 7522
# STAT_n_D 28076
# STAT_n_A 37460
# STAT_CC_D 49
# STAT_CC_A 2
# STAT_CC_D_An 1
# STAT_CC_A_Ca 1
# ABS_wf_D 0.26230172261004886
# ABS_f_D 0.42840576171875
# DISS_f10_D 0.9947998290354751
# DISS_wf10_D 0.6909782618994349
# CT_f_e_conn 0.18665248604094656
# CT_f_conn_D_An 0.27432682718335943
# CT_f_conn_A_Ca 0.9953817405232248
# CT_e_conn 1404
# CT_e_D_An 1466
# CT_e_A_Ca 7630
# CT_n_D_adj_An 512
# CT_n_A_adj_Ca 512
# CT_f_D_tort1 0.700077901843677
# CT_f_A_tort1 0.2088127229329257
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.514_3.4_000500.txt
# STAT_n 65536
# STAT_e 3727
# STAT_n_D 31856
# STAT_n_A 33680
# STAT_CC_D 7
# STAT_CC_A 5
# STAT_CC_D_An 1
# STAT_CC_A_Ca 1
# ABS_wf_D 0.294863269204334
# ABS_f_D 0.486083984375
# DISS_f10_D 0.8665871421396283
# DISS_wf10_D 0.4513284545278171
# CT_f_e_conn 0.23879796082640192
# CT_f_conn_D_An 0.7476770467101959
# CT_f_conn_A_Ca 0.6040380047505938
# CT_e_conn 890
# CT_e_D_An 2577
# CT_e_A_Ca 2072
# CT_n_D_adj_An 512
# CT_n_A_adj_Ca 512
# CT_f_D_tort1 0.43101855739356787
# CT_f_A_tort1 0.49282343688556823
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.586_3.6_007220.txt
# STAT_n 65536
# STAT_e 1854
# STAT_n_D 27221
# STAT_n_A 38315
# STAT_CC_D 7
# STAT_CC_A 1
# STAT_CC_D_An 1
# STAT_CC_A_Ca 1
# ABS_wf_D 0.24785949741537192
# ABS_f_D 0.4153594970703125
# DISS_f10_D 0.489585246684545
# DISS_wf10_D 0.2597744141343992
# CT_f_e_conn 0.3775620280474649
# CT_f_conn_D_An 0.3842254142022703
# CT_f_conn_A_Ca 1.0
# CT_e_conn 700
# CT_e_D_An 700
# CT_e_A_Ca 1872
# CT_n_D_adj_An 512
# CT_n_A_adj_Ca 512
# CT_f_D_tort1 1.0
# CT_f_A_tort1 0.623489494975858
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.528_3.2_000880.txt
# STAT_n 65536
# STAT_e 3129
# STAT_n_D 30757
# STAT_n_A 34779
# STAT_CC_D 9
# STAT_CC_A 4
# STAT_CC_D_An 1
# STAT_CC_A_Ca 1
# ABS_wf_D 0.2880492732835954
# ABS_f_D 0.4693145751953125
# DISS_f10_D 0.7631433494814188
# DISS_wf10_D 0.3911658025684784
# CT_f_e_conn 0.5183764781080218
# CT_f_conn_D_An 0.6974997561530708
# CT_f_conn_A_Ca 0.9577043618275396
# CT_e_conn 1622
# CT_e_D_An 1882
# CT_e_A_Ca 2905
# CT_n_D_adj_An 512
# CT_n_A_adj_Ca 512
# CT_f_D_tort1 0.6351093087213909
# CT_f_A_tort1 0.37042152035547016
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.5_2.6_004020.txt
# STAT_n 65536
# STAT_e 1259
# STAT_n_D 32927
# STAT_n_A 32609
# STAT_CC_D 1
# STAT_CC_A 2
# STAT_CC_D_An 1
# STAT_CC_A_Ca 1
# ABS_wf_D 0.31466602468453303
# ABS_f_D 0.5024261474609375
# DISS_f10_D 0.3140280013362894
# DISS_wf10_D 0.15951230250094872
# CT_f_e_conn 0.7776012708498808
# CT_f_conn_D_An 1.0
# CT_f_conn_A_Ca 0.8979116194915514
# CT_e_conn 979
# CT_e_D_An 1263
# CT_e_A_Ca 979
# CT_n_D_adj_An 512
# CT_n_A_adj_Ca 512
# CT_f_D_tort1 0.7177088711391867
# CT_f_A_tort1 0.9097677595628415
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.558_3.6_000420.txt
# STAT_n 65536
# STAT_e 3760
# STAT_n_D 28908
# STAT_n_A 36628
# STAT_CC_D 15
# STAT_CC_A 2
# STAT_CC_D_An 1
# STAT_CC_A_Ca 1
# ABS_wf_D 0.26980681353296576
# ABS_f_D 0.44110107421875
# DISS_f10_D 0.8558530510585305
# DISS_wf10_D 0.4610826007290346
# CT_f_e_conn 0.2425531914893617
# CT_f_conn_D_An 0.3280406807804068
# CT_f_conn_A_Ca 0.995003822212515
# CT_e_conn 912
# CT_e_D_An 912
# CT_e_A_Ca 3768
# CT_n_D_adj_An 512
# CT_n_A_adj_Ca 512
# CT_f_D_tort1 0.9656226932405357
# CT_f_A_tort1 0.24960899986280696
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.615_4.0_000160.txt
# STAT_n 40501
# STAT_e 3466
# STAT_n_D 16223
# STAT_n_A 24278
# STAT_CC_D 46
# STAT_CC_A 1
# STAT_CC_D_An 8
# STAT_CC_A_Ca 1
# ABS_wf_D 0.25319978887832595
# ABS_f_D 0.4005580109133108
# DISS_f10_D 0.9873636195524872
# DISS_wf10_D 0.5867521718871512
# CT_f_e_conn 0.12463935372186959
# CT_f_conn_D_An 0.13419219626456266
# CT_f_conn_A_Ca 1.0
# CT_e_conn 432
# CT_e_D_An 416
# CT_e_A_Ca 3599
# CT_n_D_adj_An 147
# CT_n_A_adj_Ca 197
# CT_f_D_tort1 0.8902158934313276
# CT_f_A_tort1 0.26583738363950904
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.514_2.6_000980.txt
# STAT_n 65536
# STAT_e 1711
# STAT_n_D 31663
# STAT_n_A 33873
# STAT_CC_D 3
# STAT_CC_A 2
# STAT_CC_D_An 1
# STAT_CC_A_Ca 1
# ABS_wf_D 0.297939100584844
# ABS_f_D 0.4831390380859375
# DISS_f10_D 0.43031298360862835
# DISS_wf10_D 0.2185368871245811
# CT_f_e_conn 0.4547048509643483
# CT_f_conn_D_An 0.7606038593942457
# CT_f_conn_A_Ca 0.8376287898916541
# CT_e_conn 778
# CT_e_D_An 1152
# CT_e_A_Ca 1347
# CT_n_D_adj_An 512
# CT_n_A_adj_Ca 512
# CT_f_D_tort1 0.6938919569821036
# CT_f_A_tort1 0.5613435308215557
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.514_4.0_000040.txt
# STAT_n 65536
# STAT_e 7021
# STAT_n_D 31979
# STAT_n_A 33557
# STAT_CC_D 15
# STAT_CC_A 14
# STAT_CC_D_An 1
# STAT_CC_A_Ca 1
# ABS_wf_D 0.29520183029469643
# ABS_f_D 0.4879608154296875
# DISS_f10_D 0.9946527408611902
# DISS_wf10_D 0.6599532047292265
# CT_f_e_conn 0.24512177752456915
# CT_f_conn_D_An 0.8300134463241502
# CT_f_conn_A_Ca 0.49450189230264924
# CT_e_conn 1721
# CT_e_D_An 5494
# CT_e_A_Ca 3114
# CT_n_D_adj_An 512
# CT_n_A_adj_Ca 512
# CT_f_D_tort1 0.2579211091436537
# CT_f_A_tort1 0.4110521875376642
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.5_3.6_000540.txt
# STAT_n 65536
# STAT_e 3551
# STAT_n_D 32832
# STAT_n_A 32704
# STAT_CC_D 6
# STAT_CC_A 5
# STAT_CC_D_An 1
# STAT_CC_A_Ca 1
# ABS_wf_D 0.3035009382059145
# ABS_f_D 0.5009765625
# DISS_f10_D 0.7957175925925926
# DISS_wf10_D 0.42005105824028405
# CT_f_e_conn 0.19712756969867642
# CT_f_conn_D_An 0.7635843079922028
# CT_f_conn_A_Ca 0.5680956457925636
# CT_e_conn 700
# CT_e_D_An 2451
# CT_e_A_Ca 1828
# CT_n_D_adj_An 512
# CT_n_A_adj_Ca 512
# CT_f_D_tort1 0.40370961308336656
# CT_f_A_tort1 0.4988966036923408
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.528_3.8_007080.txt
# STAT_n 65536
# STAT_e 1816
# STAT_n_D 30944
# STAT_n_A 34592
# STAT_CC_D 3
# STAT_CC_A 1
# STAT_CC_D_An 1
# STAT_CC_A_Ca 1
# ABS_wf_D 0.2782160289306138
# ABS_f_D 0.47216796875
# DISS_f10_D 0.45013572905894517
# DISS_wf10_D 0.23318398040122934
# CT_f_e_conn 0.7004405286343612
# CT_f_conn_D_An 0.6395747156153051
# CT_f_conn_A_Ca 1.0
# CT_e_conn 1272
# CT_e_D_An 1272
# CT_e_A_Ca 1820
# CT_n_D_adj_An 512
# CT_n_A_adj_Ca 512
# CT_f_D_tort1 0.5450457278560962
# CT_f_A_tort1 0.5341697502312673
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.528_3.8_000100.txt
# STAT_n 65536
# STAT_e 5660
# STAT_n_D 30834
# STAT_n_A 34702
# STAT_CC_D 19
# STAT_CC_A 3
# STAT_CC_D_An 1
# STAT_CC_A_Ca 1
# ABS_wf_D 0.28538255552893516
# ABS_f_D 0.470489501953125
# DISS_f10_D 0.988973211390024
# DISS_wf10_D 0.600309471836602
# CT_f_e_conn 0.32402826855123673
# CT_f_conn_D_An 0.404553415061296
# CT_f_conn_A_Ca 0.9923635525329952
# CT_e_conn 1834
# CT_e_D_An 1953
# CT_e_A_Ca 5607
# CT_n_D_adj_An 512
# CT_n_A_adj_Ca 512
# CT_f_D_tort1 0.5872214205547539
# CT_f_A_tort1 0.22414844498649708
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.586_4.0_006740.txt
# STAT_n 65536
# STAT_e 1813
# STAT_n_D 27323
# STAT_n_A 38213
# STAT_CC_D 5
# STAT_CC_A 1
# STAT_CC_D_An 1
# STAT_CC_A_Ca 1
# ABS_wf_D 0.24613192771769493
# ABS_f_D 0.4169158935546875
# DISS_f10_D 0.49072210225817076
# DISS_wf10_D 0.2598311145089259
# CT_f_e_conn 0.31991174848317705
# CT_f_conn_D_An 0.20715148409764667
# CT_f_conn_A_Ca 1.0
# CT_e_conn 580
# CT_e_D_An 580
# CT_e_A_Ca 1825
# CT_n_D_adj_An 512
# CT_n_A_adj_Ca 512
# CT_f_D_tort1 1.0
# CT_f_A_tort1 0.6413785884384895
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.558_2.4_002420.txt
# STAT_n 65536
# STAT_e 1817
# STAT_n_D 27183
# STAT_n_A 38353
# STAT_CC_D 4
# STAT_CC_A 1
# STAT_CC_D_An 1
# STAT_CC_A_Ca 1
# ABS_wf_D 0.24229425582166292
# ABS_f_D 0.4147796630859375
# DISS_f10_D 0.5337895007909355
# DISS_wf10_D 0.2734803062736874
# CT_f_e_conn 0.42102366538249864
# CT_f_conn_D_An 0.44766949931942757
# CT_f_conn_A_Ca 1.0
# CT_e_conn 765
# CT_e_D_An 764
# CT_e_A_Ca 1825
# CT_n_D_adj_An 512
# CT_n_A_adj_Ca 512
# CT_f_D_tort1 1.0
# CT_f_A_tort1 0.3285271034860376
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.558_3.2_000400.txt
# STAT_n 65536
# STAT_e 3770
# STAT_n_D 28546
# STAT_n_A 36990
# STAT_CC_D 16
# STAT_CC_A 2
# STAT_CC_D_An 1
# STAT_CC_A_Ca 1
# ABS_wf_D 0.26754743833486544
# ABS_f_D 0.435577392578125
# DISS_f10_D 0.8738877601064948
# DISS_wf10_D 0.4706130405057016
# CT_f_e_conn 0.4379310344827586
# CT_f_conn_D_An 0.5570307573740629
# CT_f_conn_A_Ca 0.9802379021357124
# CT_e_conn 1651
# CT_e_D_An 1790
# CT_e_A_Ca 3685
# CT_n_D_adj_An 512
# CT_n_A_adj_Ca 512
# CT_f_D_tort1 0.6110307527828438
# CT_f_A_tort1 0.35028544637193526
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.586_2.8_000280.txt
# STAT_n 65536
# STAT_e 2655
# STAT_n_D 25982
# STAT_n_A 39554
# STAT_CC_D 12
# STAT_CC_A 1
# STAT_CC_D_An 1
# STAT_CC_A_Ca 1
# ABS_wf_D 0.2438795938697451
# ABS_f_D 0.396453857421875
# DISS_f10_D 0.6872065275960281
# DISS_wf10_D 0.36957773977550235
# CT_f_e_conn 0.38267419962335214
# CT_f_conn_D_An 0.46859364175198215
# CT_f_conn_A_Ca 1.0
# CT_e_conn 1016
# CT_e_D_An 1015
# CT_e_A_Ca 2695
# CT_n_D_adj_An 512
# CT_n_A_adj_Ca 512
# CT_f_D_tort1 0.9040657084188912
# CT_f_A_tort1 0.49719370986499467
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.528_3.4_000140.txt
# STAT_n 65536
# STAT_e 5328
# STAT_n_D 30795
# STAT_n_A 34741
# STAT_CC_D 15
# STAT_CC_A 4
# STAT_CC_D_An 1
# STAT_CC_A_Ca 1
# ABS_wf_D 0.28515894390958324
# ABS_f_D 0.4698944091796875
# DISS_f10_D 0.9873356064296152
# DISS_wf10_D 0.5837042422073516
# CT_f_e_conn 0.4363738738738739
# CT_f_conn_D_An 0.5987985062510148
# CT_f_conn_A_Ca 0.9207852393425635
# CT_e_conn 2325
# CT_e_D_An 2946
# CT_e_A_Ca 4757
# CT_n_D_adj_An 512
# CT_n_A_adj_Ca 512
# CT_f_D_tort1 0.38107375271149674
# CT_f_A_tort1 0.2846290912501172
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.5_2.6_000160.txt
# STAT_n 40501
# STAT_e 2004
# STAT_n_D 20193
# STAT_n_A 20308
# STAT_CC_D 10
# STAT_CC_A 9
# STAT_CC_D_An 5
# STAT_CC_A_Ca 5
# ABS_wf_D 0.3165592285854695
# ABS_f_D 0.4985802819683465
# DISS_f10_D 0.7695736146189274
# DISS_wf10_D 0.3820047308047105
# CT_f_e_conn 0.4740518962075848
# CT_f_conn_D_An 0.8103798345961472
# CT_f_conn_A_Ca 0.7248375024620839
# CT_e_conn 950
# CT_e_D_An 1549
# CT_e_A_Ca 1415
# CT_n_D_adj_An 186
# CT_n_A_adj_Ca 233
# CT_f_D_tort1 0.37166951845514545
# CT_f_A_tort1 0.4591711956521739
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.543_2.6_000060.txt
# STAT_n 65536
# STAT_e 3777
# STAT_n_D 28705
# STAT_n_A 36831
# STAT_CC_D 11
# STAT_CC_A 4
# STAT_CC_D_An 1
# STAT_CC_A_Ca 1
# ABS_wf_D 0.26655821069013413
# ABS_f_D 0.4380035400390625
# DISS_f10_D 0.9069500087092841
# DISS_wf10_D 0.4845977719957217
# CT_f_e_conn 0.3666931427058512
# CT_f_conn_D_An 0.6475178540323986
# CT_f_conn_A_Ca 0.7858325866796991
# CT_e_conn 1385
# CT_e_D_An 2222
# CT_e_A_Ca 2843
# CT_n_D_adj_An 512
# CT_n_A_adj_Ca 512
# CT_f_D_tort1 0.429009522784742
# CT_f_A_tort1 0.4352347717928342
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.543_2.8_006140.txt
# STAT_n 65536
# STAT_e 1280
# STAT_n_D 29671
# STAT_n_A 35865
# STAT_CC_D 2
# STAT_CC_A 1
# STAT_CC_D_An 1
# STAT_CC_A_Ca 1
# ABS_wf_D 0.24803367013570884
# ABS_f_D 0.4527435302734375
# DISS_f10_D 0.3633177176367497
# DISS_wf10_D 0.1905690977863057
# CT_f_e_conn 0.5953125
# CT_f_conn_D_An 0.6562636918202959
# CT_f_conn_A_Ca 1.0
# CT_e_conn 762
# CT_e_D_An 762
# CT_e_A_Ca 1282
# CT_n_D_adj_An 512
# CT_n_A_adj_Ca 512
# CT_f_D_tort1 0.9768898931799507
# CT_f_A_tort1 0.5834936567684372
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.514_2.6_000080.txt
# STAT_n 65536
# STAT_e 3479
# STAT_n_D 31494
# STAT_n_A 34042
# STAT_CC_D 7
# STAT_CC_A 4
# STAT_CC_D_An 1
# STAT_CC_A_Ca 1
# ABS_wf_D 0.2905818965876171
# ABS_f_D 0.480560302734375
# DISS_f10_D 0.8202514764717089
# DISS_wf10_D 0.4264204684552755
# CT_f_e_conn 0.4610520264443806
# CT_f_conn_D_An 0.6215152092462056
# CT_f_conn_A_Ca 0.9257681687327419
# CT_e_conn 1604
# CT_e_D_An 2002
# CT_e_A_Ca 3109
# CT_n_D_adj_An 512
# CT_n_A_adj_Ca 512
# CT_f_D_tort1 0.47946255236538265
# CT_f_A_tort1 0.3617007774075837
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.5_2.8_000380.txt
# STAT_n 65536
# STAT_e 2171
# STAT_n_D 32818
# STAT_n_A 32718
# STAT_CC_D 3
# STAT_CC_A 2
# STAT_CC_D_An 1
# STAT_CC_A_Ca 1
# ABS_wf_D 0.3000417589060818
# ABS_f_D 0.500762939453125
# DISS_f10_D 0.5336400755682857
# DISS_wf10_D 0.2704108235114687
# CT_f_e_conn 0.7438968217411331
# CT_f_conn_D_An 0.8805228837832897
# CT_f_conn_A_Ca 0.9042423130998227
# CT_e_conn 1615
# CT_e_D_An 1871
# CT_e_A_Ca 1923
# CT_n_D_adj_An 512
# CT_n_A_adj_Ca 512
# CT_f_D_tort1 0.6753988303284078
# CT_f_A_tort1 0.588135879668751
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.514_2.4_000220.txt
# STAT_n 65536
# STAT_e 2685
# STAT_n_D 30979
# STAT_n_A 34557
# STAT_CC_D 8
# STAT_CC_A 3
# STAT_CC_D_An 1
# STAT_CC_A_Ca 1
# ABS_wf_D 0.289437642232258
# ABS_f_D 0.4727020263671875
# DISS_f10_D 0.6420155589270151
# DISS_wf10_D 0.33095443578530515
# CT_f_e_conn 0.42048417132216015
# CT_f_conn_D_An 0.5464992414216082
# CT_f_conn_A_Ca 0.9760395867696848
# CT_e_conn 1129
# CT_e_D_An 1285
# CT_e_A_Ca 2557
# CT_n_D_adj_An 512
# CT_n_A_adj_Ca 512
# CT_f_D_tort1 0.6683402244536326
# CT_f_A_tort1 0.5629576921936612
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.543_4.0_000080.txt
# STAT_n 65536
# STAT_e 5728
# STAT_n_D 29982
# STAT_n_A 35554
# STAT_CC_D 19
# STAT_CC_A 4
# STAT_CC_D_An 1
# STAT_CC_A_Ca 1
# ABS_wf_D 0.2783229167448315
# ABS_f_D 0.457489013671875
# DISS_f10_D 0.9865586018277633
# DISS_wf10_D 0.6086847421142769
# CT_f_e_conn 0.25104748603351956
# CT_f_conn_D_An 0.4975318524448002
# CT_f_conn_A_Ca 0.8469370534960905
# CT_e_conn 1438
# CT_e_D_An 2435
# CT_e_A_Ca 4799
# CT_n_D_adj_An 512
# CT_n_A_adj_Ca 512
# CT_f_D_tort1 0.48086076288798013
# CT_f_A_tort1 0.27527231668437835
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.558_2.6_000100.txt
# STAT_n 65536
# STAT_e 3283
# STAT_n_D 27362
# STAT_n_A 38174
# STAT_CC_D 14
# STAT_CC_A 2
# STAT_CC_D_An 1
# STAT_CC_A_Ca 1
# ABS_wf_D 0.25720280543750995
# ABS_f_D 0.417510986328125
# DISS_f10_D 0.8060448797602514
# DISS_wf10_D 0.43167723145526965
# CT_f_e_conn 0.2921108742004264
# CT_f_conn_D_An 0.36715152401140266
# CT_f_conn_A_Ca 0.9884476345156389
# CT_e_conn 959
# CT_e_D_An 1036
# CT_e_A_Ca 3252
# CT_n_D_adj_An 512
# CT_n_A_adj_Ca 512
# CT_f_D_tort1 0.8780609197690623
# CT_f_A_tort1 0.3631569183473352
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.528_2.6_006300.txt
# STAT_n 65536
# STAT_e 1129
# STAT_n_D 30539
# STAT_n_A 34997
# STAT_CC_D 2
# STAT_CC_A 2
# STAT_CC_D_An 1
# STAT_CC_A_Ca 1
# ABS_wf_D 0.30536239684154265
# ABS_f_D 0.4659881591796875
# DISS_f10_D 0.29644061691607454
# DISS_wf10_D 0.15272295617849177
# CT_f_e_conn 0.6829052258635961
# CT_f_conn_D_An 0.9768492746979273
# CT_f_conn_A_Ca 0.9363088264708403
# CT_e_conn 771
# CT_e_D_An 1005
# CT_e_A_Ca 903
# CT_n_D_adj_An 512
# CT_n_A_adj_Ca 512
# CT_f_D_tort1 0.8129860552426924
# CT_f_A_tort1 0.873443603515625
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.586_2.6_000220.txt
# STAT_n 65536
# STAT_e 3037
# STAT_n_D 24927
# STAT_n_A 40609
# STAT_CC_D 17
# STAT_CC_A 1
# STAT_CC_D_An 1
# STAT_CC_A_Ca 1
# ABS_wf_D 0.23671900364243542
# ABS_f_D 0.3803558349609375
# DISS_f10_D 0.7584948048301039
# DISS_wf10_D 0.417697005579926
# CT_f_e_conn 0.22653934804082976
# CT_f_conn_D_An 0.31331487944798814
# CT_f_conn_A_Ca 1.0
# CT_e_conn 688
# CT_e_D_An 688
# CT_e_A_Ca 3097
# CT_n_D_adj_An 512
# CT_n_A_adj_Ca 512
# CT_f_D_tort1 1.0
# CT_f_A_tort1 0.2886059740451624
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.572_3.8_006980.txt
# STAT_n 65536
# STAT_e 1814
# STAT_n_D 28207
# STAT_n_A 37329
# STAT_CC_D 5
# STAT_CC_A 1
# STAT_CC_D_An 1
# STAT_CC_A_Ca 1
# ABS_wf_D 0.2474244021635515
# ABS_f_D 0.4304046630859375
# DISS_f10_D 0.4769738008295813
# DISS_wf10_D 0.25307136205833985
# CT_f_e_conn 0.33076074972436603
# CT_f_conn_D_An 0.22671677243237495
# CT_f_conn_A_Ca 1.0
# CT_e_conn 600
# CT_e_D_An 600
# CT_e_A_Ca 1826
# CT_n_D_adj_An 512
# CT_n_A_adj_Ca 512
# CT_f_D_tort1 1.0
# CT_f_A_tort1 0.49420021966835437
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.514_2.8_000200.txt
# STAT_n 65536
# STAT_e 2521
# STAT_n_D 31468
# STAT_n_A 34068
# STAT_CC_D 9
# STAT_CC_A 2
# STAT_CC_D_An 1
# STAT_CC_A_Ca 1
# ABS_wf_D 0.29307525623046904
# ABS_f_D 0.48016357421875
# DISS_f10_D 0.5796682343968476
# DISS_wf10_D 0.2998762924757
# CT_f_e_conn 0.3451011503371678
# CT_f_conn_D_An 0.6235223083767637
# CT_f_conn_A_Ca 0.8389691205823647
# CT_e_conn 870
# CT_e_D_An 1318
# CT_e_A_Ca 2101
# CT_n_D_adj_An 512
# CT_n_A_adj_Ca 512
# CT_f_D_tort1 0.706284083380052
# CT_f_A_tort1 0.5085018543139038
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.5_3.8_001820.txt
# STAT_n 65536
# STAT_e 2396
# STAT_n_D 32748
# STAT_n_A 32788
# STAT_CC_D 1
# STAT_CC_A 4
# STAT_CC_D_An 1
# STAT_CC_A_Ca 1
# ABS_wf_D 0.2945634519758941
# ABS_f_D 0.49969482421875
# DISS_f10_D 0.6038536704531574
# DISS_wf10_D 0.30664641375045015
# CT_f_e_conn 0.3501669449081803
# CT_f_conn_D_An 1.0
# CT_f_conn_A_Ca 0.3808100524582164
# CT_e_conn 839
# CT_e_D_An 2401
# CT_e_A_Ca 839
# CT_n_D_adj_An 512
# CT_n_A_adj_Ca 512
# CT_f_D_tort1 0.33559301331379016
# CT_f_A_tort1 0.8886753163543168
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.514_2.8_005540.txt
# STAT_n 65536
# STAT_e 1484
# STAT_n_D 31702
# STAT_n_A 33834
# STAT_CC_D 3
# STAT_CC_A 2
# STAT_CC_D_An 1
# STAT_CC_A_Ca 1
# ABS_wf_D 0.2774564462142751
# ABS_f_D 0.483734130859375
# DISS_f10_D 0.37275250772821905
# DISS_wf10_D 0.19350177054694004
# CT_f_e_conn 0.4838274932614555
# CT_f_conn_D_An 0.7063907639896536
# CT_f_conn_A_Ca 0.8493231660459892
# CT_e_conn 718
# CT_e_D_An 965
# CT_e_A_Ca 1245
# CT_n_D_adj_An 512
# CT_n_A_adj_Ca 512
# CT_f_D_tort1 0.8036527641332499
# CT_f_A_tort1 0.654266425389755
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.528_4.0_001100.txt
# STAT_n 65536
# STAT_e 2743
# STAT_n_D 31059
# STAT_n_A 34477
# STAT_CC_D 2
# STAT_CC_A 5
# STAT_CC_D_An 1
# STAT_CC_A_Ca 1
# ABS_wf_D 0.2841926540460489
# ABS_f_D 0.4739227294921875
# DISS_f10_D 0.6881419234360411
# DISS_wf10_D 0.3486671441696059
# CT_f_e_conn 0.6303317535545023
# CT_f_conn_D_An 0.9375060368975177
# CT_f_conn_A_Ca 0.7481219363633727
# CT_e_conn 1729
# CT_e_D_An 2523
# CT_e_A_Ca 1961
# CT_n_D_adj_An 512
# CT_n_A_adj_Ca 512
# CT_f_D_tort1 0.40500721203379353
# CT_f_A_tort1 0.5312681735354553
#
#
# Descriptors for morphology: ../data/2phase/2D-morphologies/data/data_0.543_3.4_001960.txt
# STAT_n 65536
# STAT_e 2170
# STAT_n_D 29844
# STAT_n_A 35692
# STAT_CC_D 6
# STAT_CC_A 1
# STAT_CC_D_An 1
# STAT_CC_A_Ca 1
# ABS_wf_D 0.281161466408089
# ABS_f_D 0.45538330078125
# DISS_f10_D 0.5614528883527677
# DISS_wf10_D 0.28741365139623565
# CT_f_e_conn 0.4110599078341014
# CT_f_conn_D_An 0.4593218067283206
# CT_f_conn_A_Ca 1.0
# CT_e_conn 892
# CT_e_D_An 892
# CT_e_A_Ca 2182
# CT_n_D_adj_An 512
# CT_n_A_adj_Ca 512
# CT_f_D_tort1 0.9808141231397723
# CT_f_A_tort1 0.4701613807015578
