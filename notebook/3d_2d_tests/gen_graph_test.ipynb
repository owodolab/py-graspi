# %%
import hwi_new_igraph_testing as ig
import importlib
import descriptors as ds
import os
import time
import matplotlib.pyplot as plt
import tracemalloc

importlib.reload(ig)  # 강제 리로드

current_dir = os.getcwd()
data_path = f"{current_dir}/graspi_igraph/data/"
descriptors_path = f"{current_dir}/graspi_igraph/p1descriptors/"
test_files = [os.path.splitext(file)[0] for file in os.listdir(data_path)]
epsilon=1e-5

times = []
mems = []
time_mem_stats = {}

for test_file in test_files:
    if '100-' not in test_file and '5x' not in test_file:
        continue

    # g = ig.generateGraph(data_path + test_file + ".txt")
    import time
    tracemalloc.start()
    graph_start = time.time()
    g,is_2d = ig.generateGraphAdj(data_path + test_file + ".txt")
    _stats = tracemalloc.get_traced_memory()
    graph_end = time.time()     
    tracemalloc.stop()
    graph_mem = _stats[1]-_stats[0]  
    stats = ds.desciptors(g)
    #ig.visual2D(g, 'graph')

    print(f"{test_file} Results")

    with open(descriptors_path + "p1descriptors." + test_file + ".log") as f:
        for line in f:
            stat = line.strip().split(" ")
            try:
                # if stats.get(stat[0], -1) == int(stat[1]):
                if abs(stats.get(stat[0], -1) - float(stat[1])) < epsilon:
                    print(f"{stat[0]} passed")
                elif stats.get(stat[0], -1) != -1 and stats.get(stat[0], -1) != int(stat[1]):
                    print(f"{stat[0]} failed - {stats.get(stat[0])} is not the same as expected {stat[1]}")
            except ValueError:
                if abs(stats.get(stat[0], -1) - float(stat[1])) < epsilon:
                    print(f"{stat[0]} passed")
                elif stats.get(stat[0], -1) != -1 and stats.get(stat[0], -1) != float(stat[1]):
                    print(f"{stat[0]} failed - {stats.get(stat[0])} is not the same as expected {stat[1]}")
    descriptor_time = stats["time"]
    descriptor_mem = stats["mem"]

    times.append(descriptor_time)
    mems.append(descriptor_mem)

    graph_time = graph_end-graph_start
    print(f"Total time to calculate graph: {graph_time} second(s)")
    print(f"Total time to calculate descriptors: {descriptor_time} second(s)")
    print(f"Peak memory usage for graph generation: {graph_mem} bytes")
    print(f"Peak memory usage for descriptor calculation: {descriptor_mem} bytes")
    print(stats)
    print("")
    time_mem_stats[test_file] = {"graph_time": graph_time, "descriptor_time": descriptor_time,  "graph_mem":graph_mem, "descriptor_mem": descriptor_mem}
# Out:
# const adj time :  0.17059087753295898
# vertexcolor time :  0.001046895980834961
# others time :  0.19324612617492676
# loop time :  1.4921042919158936
# testFile-100-2D Results
# STAT_n passed
# STAT_e passed
# STAT_n_D passed
# STAT_n_A passed
# STAT_CC_D passed
# STAT_CC_A passed
# STAT_CC_D_An passed
# STAT_CC_A_Ca passed
# ABS_f_D passed
# CT_f_conn_D_An passed
# CT_f_conn_A_Ca passed
# CT_n_D_adj_An failed - 0 is not the same as expected 1
# CT_n_A_adj_Ca failed - 0 is not the same as expected 1
# Total time to calculate graph: 1.8636510372161865 second(s)
# Total time to calculate descriptors: 0.9238529205322266 second(s)
# Peak memory usage for graph generation: 5150305 bytes
# Peak memory usage for descriptor calculation: 77643 bytes
# {'STAT_n': 10000, 'STAT_e': 100, 'STAT_n_D': 5000, 'STAT_n_A': 5000, 'STAT_CC_D': 1, 'STAT_CC_A': 1, 'STAT_CC_D_An': 0, 'STAT_CC_A_Ca': 0, 'ABS_f_D': 0.5, 'CT_f_conn_D_An': 0.0, 'CT_f_conn_A_Ca': 0.0, 'CT_n_D_adj_An': 0, 'CT_n_A_adj_Ca': 0, 'time': 0.9238529205322266, 'mem': 77643}
#
# const adj time :  0.06364011764526367
# vertexcolor time :  0.0002808570861816406
# others time :  0.06103873252868652
# loop time :  0.7717649936676025
# morphology_resize_0.25x Results
# STAT_n passed
# STAT_e passed
# STAT_n_D passed
# STAT_n_A passed
# STAT_CC_D passed
# STAT_CC_A passed
# STAT_CC_D_An passed
# STAT_CC_A_Ca passed
# ABS_f_D passed
# CT_f_conn_D_An passed
# CT_f_conn_A_Ca passed
# CT_n_D_adj_An failed - 48 is not the same as expected 49
# CT_n_A_adj_Ca failed - 29 is not the same as expected 30
# Total time to calculate graph: 0.89927077293396 second(s)
# Total time to calculate descriptors: 0.3948841094970703 second(s)
# Peak memory usage for graph generation: 1878456 bytes
# Peak memory usage for descriptor calculation: 28907 bytes
# {'STAT_n': 3780, 'STAT_e': 613, 'STAT_n_D': 2035, 'STAT_n_A': 1745, 'STAT_CC_D': 7, 'STAT_CC_A': 1, 'STAT_CC_D_An': 3, 'STAT_CC_A_Ca': 1, 'ABS_f_D': 0.53836, 'CT_f_conn_D_An': 0.287961, 'CT_f_conn_A_Ca': 1.0, 'CT_n_D_adj_An': 48, 'CT_n_A_adj_Ca': 29, 'time': 0.3948841094970703, 'mem': 28907}
#
# const adj time :  0.0006489753723144531
# vertexcolor time :  6.127357482910156e-05
# others time :  0.0013170242309570312
# loop time :  0.013094902038574219
# data_5x4x3 Results
# STAT_n passed
# STAT_e passed
# STAT_n_D passed
# STAT_n_A passed
# STAT_CC_D passed
# STAT_CC_A passed
# STAT_CC_D_An passed
# STAT_CC_A_Ca passed
# ABS_f_D passed
# CT_f_conn_D_An passed
# CT_f_conn_A_Ca passed
# CT_n_D_adj_An failed - 9 is not the same as expected 13
# CT_n_A_adj_Ca failed - 6 is not the same as expected 9
# Total time to calculate graph: 0.015386819839477539 second(s)
# Total time to calculate descriptors: 0.010555028915405273 second(s)
# Peak memory usage for graph generation: 17778 bytes
# Peak memory usage for descriptor calculation: 389 bytes
# {'STAT_n': 60, 'STAT_e': 48, 'STAT_n_D': 36, 'STAT_n_A': 24, 'STAT_CC_D': 2, 'STAT_CC_A': 2, 'STAT_CC_D_An': 2, 'STAT_CC_A_Ca': 2, 'ABS_f_D': 0.6, 'CT_f_conn_D_An': 1.0, 'CT_f_conn_A_Ca': 1.0, 'CT_n_D_adj_An': 9, 'CT_n_A_adj_Ca': 6, 'time': 0.010555028915405273, 'mem': 389}
#
# const adj time :  0.27106165885925293
# vertexcolor time :  0.0011277198791503906
# others time :  0.3661222457885742
# loop time :  3.587667942047119
# morphology_resize_0.5x Results
# STAT_n passed
# STAT_e passed
# STAT_n_D passed
# STAT_n_A passed
# STAT_CC_D passed
# STAT_CC_A passed
# STAT_CC_D_An passed
# STAT_CC_A_Ca passed
# ABS_f_D passed
# CT_f_conn_D_An passed
# CT_f_conn_A_Ca passed
# CT_n_D_adj_An failed - 94 is not the same as expected 95
# CT_n_A_adj_Ca failed - 54 is not the same as expected 55
# Total time to calculate graph: 4.2375617027282715 second(s)
# Total time to calculate descriptors: 1.44166898727417 second(s)
# Peak memory usage for graph generation: 7960413 bytes
# Peak memory usage for descriptor calculation: 121742 bytes
# {'STAT_n': 15260, 'STAT_e': 1226, 'STAT_n_D': 8226, 'STAT_n_A': 7034, 'STAT_CC_D': 7, 'STAT_CC_A': 1, 'STAT_CC_D_An': 3, 'STAT_CC_A_Ca': 1, 'ABS_f_D': 0.539056, 'CT_f_conn_D_An': 0.281668, 'CT_f_conn_A_Ca': 1.0, 'CT_n_D_adj_An': 94, 'CT_n_A_adj_Ca': 54, 'time': 1.44166898727417, 'mem': 121742}

# %%
import igraph_testing_main as ig
import importlib
import descriptors as ds
import os
import time
import matplotlib.pyplot as plt
import tracemalloc

importlib.reload(ig)  # 강제 리로드

current_dir = os.getcwd()
data_path = f"{current_dir}/graspi_igraph/data/"
descriptors_path = f"{current_dir}/graspi_igraph/p1descriptors/"
test_files = [os.path.splitext(file)[0] for file in os.listdir(data_path)]
epsilon=1e-5

times = []
mems = []
time_mem_stats = {}

for test_file in test_files:
    if '100-' not in test_file and '5x' not in test_file:
        continue

    # g = ig.generateGraph(data_path + test_file + ".txt")
    import time
    tracemalloc.start()
    graph_start = time.time()
    g,is_2D, black_vertices, white_vertices, black_green, black_interface_red, white_interface_blue, dim, interface_edge_comp_paths, shortest_path_to_red, shortest_path_to_blue, CT_n_D_adj_An, CT_n_A_adj_Ca= ig.generateGraph(data_path + test_file + ".txt")
    graph_end = time.time()
    stats = ds.desciptors(g)
    tracemalloc.stop()
    graph_mem = _stats[1]-_stats[0]  
    #ig.visual2D(g, 'graph')

    print(f"{test_file} Results")

    with open(descriptors_path + "p1descriptors." + test_file + ".log") as f:
        for line in f:
            stat = line.strip().split(" ")
            try:
                # if stats.get(stat[0], -1) == int(stat[1]):
                if abs(stats.get(stat[0], -1) - float(stat[1])) < epsilon:
                    print(f"{stat[0]} passed")
                elif stats.get(stat[0], -1) != -1 and stats.get(stat[0], -1) != int(stat[1]):
                    print(f"{stat[0]} failed - {stats.get(stat[0])} is not the same as expected {stat[1]}")
            except ValueError:
                if abs(stats.get(stat[0], -1) - float(stat[1])) < epsilon:
                    print(f"{stat[0]} passed")
                elif stats.get(stat[0], -1) != -1 and stats.get(stat[0], -1) != float(stat[1]):
                    print(f"{stat[0]} failed - {stats.get(stat[0])} is not the same as expected {stat[1]}")
    descriptor_time = stats["time"]
    descriptor_mem = stats["mem"]

    times.append(descriptor_time)
    mems.append(descriptor_mem)

    graph_time = graph_end-graph_start
    print(f"Total time to calculate graph: {graph_time} second(s)")
    print(f"Total time to calculate descriptors: {descriptor_time} second(s)")
    print(f"Peak memory usage for graph generation: {graph_mem} bytes")
    print(f"Peak memory usage for descriptor calculation: {descriptor_mem} bytes")
    print(stats)
    print("")
    time_mem_stats[test_file] = {"graph_time": graph_time, "descriptor_time": descriptor_time,  "graph_mem":graph_mem, "descriptor_mem": descriptor_mem}
# Out:
# const adj time :  0.4345250129699707
# shortest time :  0.013491153717041016
# loop time :  2.754865884780884
# testFile-100-2D Results
# STAT_n passed
# STAT_e passed
# STAT_n_D passed
# STAT_n_A passed
# STAT_CC_D passed
# STAT_CC_A passed
# STAT_CC_D_An passed
# STAT_CC_A_Ca passed
# ABS_f_D passed
# CT_f_conn_D_An passed
# CT_f_conn_A_Ca passed
# CT_n_D_adj_An failed - 0 is not the same as expected 1
# CT_n_A_adj_Ca failed - 0 is not the same as expected 1
# Total time to calculate graph: 5.357910871505737 second(s)
# Total time to calculate descriptors: 0.967750072479248 second(s)
# Peak memory usage for graph generation: 7960413 bytes
# Peak memory usage for descriptor calculation: 8196408 bytes
# {'STAT_n': 10000, 'STAT_e': 100, 'STAT_n_D': 5000, 'STAT_n_A': 5000, 'STAT_CC_D': 1, 'STAT_CC_A': 1, 'STAT_CC_D_An': 0, 'STAT_CC_A_Ca': 0, 'ABS_f_D': 0.5, 'CT_f_conn_D_An': 0.0, 'CT_f_conn_A_Ca': 0.0, 'CT_n_D_adj_An': 0, 'CT_n_A_adj_Ca': 0, 'time': 0.967750072479248, 'mem': 8196408}
#
# const adj time :  0.11109423637390137
# shortest time :  0.004051923751831055
# loop time :  1.2105560302734375
# morphology_resize_0.25x Results
# STAT_n passed
# STAT_e failed - 596 is not the same as expected 613
# STAT_n_D passed
# STAT_n_A passed
# STAT_CC_D passed
# STAT_CC_A passed
# STAT_CC_D_An passed
# STAT_CC_A_Ca passed
# ABS_f_D passed
# CT_f_conn_D_An passed
# CT_f_conn_A_Ca passed
# CT_n_D_adj_An failed - 48 is not the same as expected 49
# CT_n_A_adj_Ca failed - 29 is not the same as expected 30
# Total time to calculate graph: 2.080440044403076 second(s)
# Total time to calculate descriptors: 0.3965740203857422 second(s)
# Peak memory usage for graph generation: 7960413 bytes
# Peak memory usage for descriptor calculation: 2895715 bytes
# {'STAT_n': 3780, 'STAT_e': 596, 'STAT_n_D': 2035, 'STAT_n_A': 1745, 'STAT_CC_D': 7, 'STAT_CC_A': 1, 'STAT_CC_D_An': 3, 'STAT_CC_A_Ca': 1, 'ABS_f_D': 0.53836, 'CT_f_conn_D_An': 0.287961, 'CT_f_conn_A_Ca': 1.0, 'CT_n_D_adj_An': 48, 'CT_n_A_adj_Ca': 29, 'time': 0.3965740203857422, 'mem': 2895715}
#
# const adj time :  0.0012359619140625
# shortest time :  0.00012493133544921875
# loop time :  0.03463912010192871
# data_5x4x3 Results
# STAT_n passed
# STAT_e failed - 36 is not the same as expected 48
# STAT_n_D passed
# STAT_n_A passed
# STAT_CC_D passed
# STAT_CC_A passed
# STAT_CC_D_An passed
# STAT_CC_A_Ca passed
# ABS_f_D passed
# CT_f_conn_D_An passed
# CT_f_conn_A_Ca passed
# CT_n_D_adj_An failed - 12 is not the same as expected 13
# CT_n_A_adj_Ca failed - 8 is not the same as expected 9
# Total time to calculate graph: 0.05248379707336426 second(s)
# Total time to calculate descriptors: 0.009341955184936523 second(s)
# Peak memory usage for graph generation: 7960413 bytes
# Peak memory usage for descriptor calculation: 41585 bytes
# {'STAT_n': 60, 'STAT_e': 36, 'STAT_n_D': 36, 'STAT_n_A': 24, 'STAT_CC_D': 2, 'STAT_CC_A': 2, 'STAT_CC_D_An': 2, 'STAT_CC_A_Ca': 2, 'ABS_f_D': 0.6, 'CT_f_conn_D_An': 1.0, 'CT_f_conn_A_Ca': 1.0, 'CT_n_D_adj_An': 12, 'CT_n_A_adj_Ca': 8, 'time': 0.009341955184936523, 'mem': 41585}
#
# const adj time :  0.6209840774536133
# shortest time :  0.015867233276367188
# loop time :  4.758090019226074
# morphology_resize_0.5x Results
# STAT_n passed
# STAT_e failed - 1208 is not the same as expected 1226
# STAT_n_D passed
# STAT_n_A passed
# STAT_CC_D passed
# STAT_CC_A passed
# STAT_CC_D_An passed
# STAT_CC_A_Ca passed
# ABS_f_D passed
# CT_f_conn_D_An passed
# CT_f_conn_A_Ca passed
# CT_n_D_adj_An failed - 94 is not the same as expected 95
# CT_n_A_adj_Ca failed - 54 is not the same as expected 55
# Total time to calculate graph: 8.657129049301147 second(s)
# Total time to calculate descriptors: 1.5562288761138916 second(s)
# Peak memory usage for graph generation: 7960413 bytes
# Peak memory usage for descriptor calculation: 11647012 bytes
# {'STAT_n': 15260, 'STAT_e': 1208, 'STAT_n_D': 8226, 'STAT_n_A': 7034, 'STAT_CC_D': 7, 'STAT_CC_A': 1, 'STAT_CC_D_An': 3, 'STAT_CC_A_Ca': 1, 'ABS_f_D': 0.539056, 'CT_f_conn_D_An': 0.281668, 'CT_f_conn_A_Ca': 1.0, 'CT_n_D_adj_An': 94, 'CT_n_A_adj_Ca': 54, 'time': 1.5562288761138916, 'mem': 11647012}
