# %%
import hwi_new_igraph_testing as ig
import importlib
import descriptors as ds
import os
import time
import matplotlib.pyplot as plt
import tracemalloc

importlib.reload(ig)  # 강제 리로드

current_dir = os.getcwd()
data_path = f"{current_dir}/graspi_igraph/data/"
descriptors_path = f"{current_dir}/graspi_igraph/p1descriptors/"
test_files = [os.path.splitext(file)[0] for file in os.listdir(data_path)]
epsilon=1e-5

times = []
mems = []
time_mem_stats = {}

targetFileName = '100-2D'
loop_cnt = 5

    
for test_file in test_files:
    if targetFileName not in test_file:
        continue

    import time
    total_graph_time = 0
    for i in range(loop_cnt):

        # g = ig.generateGraph(data_path + test_file + ".txt")
        tracemalloc.start()
        graph_start = time.time()
        g,is_2d = ig.generateGraphAdj(data_path + test_file + ".txt")
        _stats = tracemalloc.get_traced_memory()
        graph_end = time.time()     
        tracemalloc.stop()
        graph_mem = _stats[1]-_stats[0]  
        stats = ds.desciptors(g)
        total_graph_time += graph_end - graph_start
        #ig.visual2D(g, 'graph')

    print(f"{test_file} Results")

    descriptor_time = stats["time"]
    descriptor_mem = stats["mem"]

    times.append(descriptor_time)
    mems.append(descriptor_mem)

    graph_time = total_graph_time/loop_cnt
    print(f"Total time to calculate graph: {graph_time} second(s)")
    print(f"Total time to calculate descriptors: {descriptor_time} second(s)")
    print(f"Peak memory usage for graph generation: {graph_mem} bytes")
    print(f"Peak memory usage for descriptor calculation: {descriptor_mem} bytes")
    print(stats)
    print("")
    time_mem_stats[test_file] = {"graph_time": graph_time, "descriptor_time": descriptor_time,  "graph_mem":graph_mem, "descriptor_mem": descriptor_mem}
# Out:
# PART #1 time :  0.191939115524292
# PART #2 time :  0.11395883560180664
# PART #3 time :  1.4521899223327637
# PART #1 time :  0.17465591430664062
# PART #2 time :  0.10350322723388672
# PART #3 time :  1.3907661437988281
# PART #1 time :  0.1755969524383545
# PART #2 time :  0.10935521125793457
# PART #3 time :  1.4008610248565674
# PART #1 time :  0.2601509094238281
# PART #2 time :  0.08913612365722656
# PART #3 time :  1.5299739837646484
# PART #1 time :  0.17301726341247559
# PART #2 time :  0.10836601257324219
# PART #3 time :  1.4057281017303467
# testFile-100-2D Results
# Total time to calculate graph: 1.8544787406921386 second(s)
# Total time to calculate graph: 1.8293089866638184 second(s)
# Total time to calculate descriptors: 0.8647220134735107 second(s)
# Peak memory usage for graph generation: 5039233 bytes
# Peak memory usage for descriptor calculation: 79776 bytes
# {'STAT_n': 10000, 'STAT_e': 100, 'STAT_n_D': 5000, 'STAT_n_A': 5000, 'STAT_CC_D': 1, 'STAT_CC_A': 1, 'STAT_CC_D_An': 0, 'STAT_CC_A_Ca': 0, 'ABS_f_D': 0.5, 'CT_f_conn_D_An': 0.0, 'CT_f_conn_A_Ca': 0.0, 'CT_n_D_adj_An': 0, 'CT_n_A_adj_Ca': 0, 'time': 0.8647220134735107, 'mem': 79776}

# %%
import igraph_testing_main as ig
import importlib
import descriptors as ds
import os
import time
import matplotlib.pyplot as plt
import tracemalloc

importlib.reload(ig)  # 강제 리로드

current_dir = os.getcwd()
data_path = f"{current_dir}/graspi_igraph/data/"
descriptors_path = f"{current_dir}/graspi_igraph/p1descriptors/"
test_files = [os.path.splitext(file)[0] for file in os.listdir(data_path)]
epsilon=1e-5

times = []
mems = []
time_mem_stats = {}

for test_file in test_files:
    if '100-' not in test_file and '5x' not in test_file:
        continue

    # g = ig.generateGraph(data_path + test_file + ".txt")
    import time
    tracemalloc.start()
    graph_start = time.time()
    g,is_2D, black_vertices, white_vertices, black_green, black_interface_red, white_interface_blue, dim, interface_edge_comp_paths, shortest_path_to_red, shortest_path_to_blue, CT_n_D_adj_An, CT_n_A_adj_Ca= ig.generateGraph(data_path + test_file + ".txt")
    graph_end = time.time()
    stats = ds.desciptors(g)
    _stats = tracemalloc.get_traced_memory()
    tracemalloc.stop()
    graph_mem = _stats[1]-_stats[0]  
    #ig.visual2D(g, 'graph')

    print(f"{test_file} Results")

    with open(descriptors_path + "p1descriptors." + test_file + ".log") as f:
        for line in f:
            stat = line.strip().split(" ")
            try:
                # if stats.get(stat[0], -1) == int(stat[1]):
                if abs(stats.get(stat[0], -1) - float(stat[1])) < epsilon:
                    print(f"{stat[0]} passed")
                elif stats.get(stat[0], -1) != -1 and stats.get(stat[0], -1) != int(stat[1]):
                    print(f"{stat[0]} failed - {stats.get(stat[0])} is not the same as expected {stat[1]}")
            except ValueError:
                if abs(stats.get(stat[0], -1) - float(stat[1])) < epsilon:
                    print(f"{stat[0]} passed")
                elif stats.get(stat[0], -1) != -1 and stats.get(stat[0], -1) != float(stat[1]):
                    print(f"{stat[0]} failed - {stats.get(stat[0])} is not the same as expected {stat[1]}")
    descriptor_time = stats["time"]
    descriptor_mem = stats["mem"]

    times.append(descriptor_time)
    mems.append(descriptor_mem)

    graph_time = graph_end-graph_start
    print(f"Total time to calculate graph: {graph_time} second(s)")
    print(f"Total time to calculate descriptors: {descriptor_time} second(s)")
    print(f"Peak memory usage for graph generation: {graph_mem} bytes")
    print(f"Peak memory usage for descriptor calculation: {descriptor_mem} bytes")
    print(stats)
    print("")
    time_mem_stats[test_file] = {"graph_time": graph_time, "descriptor_time": descriptor_time,  "graph_mem":graph_mem, "descriptor_mem": descriptor_mem}
# Out:
# PART #1 time :  0.30706000328063965
# filter time (in PART #2): 1.8579893112182617
# PART #2 time :  1.9658489227294922
# PART #3 time :  2.6910879611968994
# testFile-100-2D Results
# STAT_n passed
# STAT_e passed
# STAT_n_D passed
# STAT_n_A passed
# STAT_CC_D passed
# STAT_CC_A passed
# STAT_CC_D_An passed
# STAT_CC_A_Ca passed
# ABS_f_D passed
# CT_f_conn_D_An passed
# CT_f_conn_A_Ca passed
# CT_n_D_adj_An failed - 0 is not the same as expected 1
# CT_n_A_adj_Ca failed - 0 is not the same as expected 1
# Total time to calculate graph: 5.070079803466797 second(s)
# Total time to calculate descriptors: 0.9235420227050781 second(s)
# Peak memory usage for graph generation: 0 bytes
# Peak memory usage for descriptor calculation: 8196668 bytes
# {'STAT_n': 10000, 'STAT_e': 100, 'STAT_n_D': 5000, 'STAT_n_A': 5000, 'STAT_CC_D': 1, 'STAT_CC_A': 1, 'STAT_CC_D_An': 0, 'STAT_CC_A_Ca': 0, 'ABS_f_D': 0.5, 'CT_f_conn_D_An': 0.0, 'CT_f_conn_A_Ca': 0.0, 'CT_n_D_adj_An': 0, 'CT_n_A_adj_Ca': 0, 'time': 0.9235420227050781, 'mem': 8196668}
#
# PART #1 time :  0.10926413536071777
# filter time (in PART #2): 0.6752121448516846
# PART #2 time :  0.7104380130767822
# PART #3 time :  1.2614860534667969
# morphology_resize_0.25x Results
# STAT_n passed
# STAT_e failed - 596 is not the same as expected 613
# STAT_n_D passed
# STAT_n_A passed
# STAT_CC_D passed
# STAT_CC_A passed
# STAT_CC_D_An passed
# STAT_CC_A_Ca passed
# ABS_f_D passed
# CT_f_conn_D_An passed
# CT_f_conn_A_Ca passed
# CT_n_D_adj_An failed - 48 is not the same as expected 49
# CT_n_A_adj_Ca failed - 29 is not the same as expected 30
# Total time to calculate graph: 2.1229963302612305 second(s)
# Total time to calculate descriptors: 0.3875739574432373 second(s)
# Peak memory usage for graph generation: 0 bytes
# Peak memory usage for descriptor calculation: 2895720 bytes
# {'STAT_n': 3780, 'STAT_e': 596, 'STAT_n_D': 2035, 'STAT_n_A': 1745, 'STAT_CC_D': 7, 'STAT_CC_A': 1, 'STAT_CC_D_An': 3, 'STAT_CC_A_Ca': 1, 'ABS_f_D': 0.53836, 'CT_f_conn_D_An': 0.287961, 'CT_f_conn_A_Ca': 1.0, 'CT_n_D_adj_An': 48, 'CT_n_A_adj_Ca': 29, 'time': 0.3875739574432373, 'mem': 2895720}
#
# PART #1 time :  0.0013282299041748047
# filter time (in PART #2): 0.012891769409179688
# PART #2 time :  0.01423501968383789
# PART #3 time :  0.03510785102844238
# data_5x4x3 Results
# STAT_n passed
# STAT_e failed - 36 is not the same as expected 48
# STAT_n_D passed
# STAT_n_A passed
# STAT_CC_D passed
# STAT_CC_A passed
# STAT_CC_D_An passed
# STAT_CC_A_Ca passed
# ABS_f_D passed
# CT_f_conn_D_An passed
# CT_f_conn_A_Ca passed
# CT_n_D_adj_An failed - 12 is not the same as expected 13
# CT_n_A_adj_Ca failed - 8 is not the same as expected 9
# Total time to calculate graph: 0.05231499671936035 second(s)
# Total time to calculate descriptors: 0.009662866592407227 second(s)
# Peak memory usage for graph generation: 0 bytes
# Peak memory usage for descriptor calculation: 37994 bytes
# {'STAT_n': 60, 'STAT_e': 36, 'STAT_n_D': 36, 'STAT_n_A': 24, 'STAT_CC_D': 2, 'STAT_CC_A': 2, 'STAT_CC_D_An': 2, 'STAT_CC_A_Ca': 2, 'ABS_f_D': 0.6, 'CT_f_conn_D_An': 1.0, 'CT_f_conn_A_Ca': 1.0, 'CT_n_D_adj_An': 12, 'CT_n_A_adj_Ca': 8, 'time': 0.009662866592407227, 'mem': 37994}
#
# PART #1 time :  0.5446162223815918
# filter time (in PART #2): 2.9038851261138916
# PART #2 time :  3.089154005050659
# PART #3 time :  5.068987131118774
# morphology_resize_0.5x Results
# STAT_n passed
# STAT_e failed - 1208 is not the same as expected 1226
# STAT_n_D passed
# STAT_n_A passed
# STAT_CC_D passed
# STAT_CC_A passed
# STAT_CC_D_An passed
# STAT_CC_A_Ca passed
# ABS_f_D passed
# CT_f_conn_D_An passed
# CT_f_conn_A_Ca passed
# CT_n_D_adj_An failed - 94 is not the same as expected 95
# CT_n_A_adj_Ca failed - 54 is not the same as expected 55
# Total time to calculate graph: 8.873507976531982 second(s)
# Total time to calculate descriptors: 1.541776180267334 second(s)
# Peak memory usage for graph generation: 0 bytes
# Peak memory usage for descriptor calculation: 11647125 bytes
# {'STAT_n': 15260, 'STAT_e': 1208, 'STAT_n_D': 8226, 'STAT_n_A': 7034, 'STAT_CC_D': 7, 'STAT_CC_A': 1, 'STAT_CC_D_An': 3, 'STAT_CC_A_Ca': 1, 'ABS_f_D': 0.539056, 'CT_f_conn_D_An': 0.281668, 'CT_f_conn_A_Ca': 1.0, 'CT_n_D_adj_An': 94, 'CT_n_A_adj_Ca': 54, 'time': 1.541776180267334, 'mem': 11647125}
