# %% [markdown]
# # Import graspi_igraph
#
# Ensure that you are only using python versions higher than 3.7
# - Python version can be checked by running *python --version* in the terminal
# - it can also be checked on notebook via *!pip --version* in the code section of the notebook

# %%
import time

# %%
import new_igraph_testing as ig
import descriptors as ds
import os
import time

current_dir = os.getcwd()
data_path = f"{current_dir}/graspi_igraph/data/"
descriptors_path = f"{current_dir}/graspi_igraph/p1descriptors/"
test_files = [os.path.splitext(file)[0] for file in os.listdir(data_path)]
epsilon=1e-5
for test_file in test_files:
    # g = ig.generateGraph(data_path + test_file + ".txt")
    import time
    graph_start = time.time()
    g,is_2d= ig.generateGraphAdj(data_path + test_file + ".txt")
    graph_end = time.time()
    stats = ds.desciptors(g)
    #ig.visual2D(g, 'graph')

    print(f"{test_file} Results")

    with open(descriptors_path + "p1descriptors." + test_file + ".log") as f:
        for line in f:
            stat = line.strip().split(" ")
            try:
                # if stats.get(stat[0], -1) == int(stat[1]):
                if abs(stats.get(stat[0], -1) - float(stat[1])) < epsilon:
                    print(f"{stat[0]} passed")
                elif stats.get(stat[0], -1) != -1 and stats.get(stat[0], -1) != int(stat[1]):
                    print(f"{stat[0]} failed - {stats.get(stat[0])} is not the same as expected {stat[1]}")
            except ValueError:
                if abs(stats.get(stat[0], -1) - float(stat[1])) < epsilon:
                    print(f"{stat[0]} passed")
                elif stats.get(stat[0], -1) != -1 and stats.get(stat[0], -1) != float(stat[1]):
                    print(f"{stat[0]} failed - {stats.get(stat[0])} is not the same as expected {stat[1]}")
    time = stats["time"]
    mem = stats["mem"]
    graph_time = graph_end-graph_start
    print(f"Total time to calculate graph: {graph_time} second(s)")
    print(f"Total time to calculate descriptors: {time} second(s)")
    print(f"Peak memory usage for descriptor calculation: {mem} bytes")
    print(stats)
    print("")
# Out:
# testFile-100-2D Results
# STAT_n passed
# STAT_e passed
# STAT_n_D passed
# STAT_n_A passed
# STAT_CC_D passed
# STAT_CC_A passed
# STAT_CC_D_An passed
# STAT_CC_A_Ca passed
# ABS_f_D passed
# CT_f_conn_D_An passed
# CT_f_conn_A_Ca passed
# CT_n_D_adj_An failed - 0 is not the same as expected 1
# CT_n_A_adj_Ca failed - 0 is not the same as expected 1
# Total time to calculate graph: 0.19545793533325195 second(s)
# Total time to calculate descriptors: 0.9458553791046143 second(s)
# Peak memory usage for descriptor calculation: 79623 bytes
# {'STAT_n': 10000, 'STAT_e': 100, 'STAT_n_D': 5000, 'STAT_n_A': 5000, 'STAT_CC_D': 1, 'STAT_CC_A': 1, 'STAT_CC_D_An': 0, 'STAT_CC_A_Ca': 0, 'ABS_f_D': 0.5, 'CT_f_conn_D_An': 0.0, 'CT_f_conn_A_Ca': 0.0, 'CT_n_D_adj_An': 0, 'CT_n_A_adj_Ca': 0, 'time': 0.9458553791046143, 'mem': 79623}
#
# data_0.528_3.8_000160 Results
# STAT_n passed
# STAT_e passed
# STAT_n_D passed
# STAT_n_A passed
# STAT_CC_D passed
# STAT_CC_A passed
# STAT_CC_D_An passed
# STAT_CC_A_Ca passed
# ABS_f_D passed
# CT_f_conn_D_An passed
# CT_f_conn_A_Ca passed
# CT_n_D_adj_An passed
# CT_n_A_adj_Ca passed
# Total time to calculate graph: 10.350841999053955 second(s)
# Total time to calculate descriptors: 3.8844730854034424 second(s)
# Peak memory usage for descriptor calculation: 322829 bytes
# {'STAT_n': 40501, 'STAT_e': 3698, 'STAT_n_D': 19268, 'STAT_n_A': 21233, 'STAT_CC_D': 22, 'STAT_CC_A': 5, 'STAT_CC_D_An': 9, 'STAT_CC_A_Ca': 3, 'ABS_f_D': 0.475741, 'CT_f_conn_D_An': 0.319545, 'CT_f_conn_A_Ca': 0.979843, 'CT_n_D_adj_An': 206, 'CT_n_A_adj_Ca': 195, 'time': 3.8844730854034424, 'mem': 322829}
#
# morphology_resize_0.25x Results
# STAT_n passed
# STAT_e passed
# STAT_n_D passed
# STAT_n_A passed
# STAT_CC_D passed
# STAT_CC_A passed
# STAT_CC_D_An passed
# STAT_CC_A_Ca passed
# ABS_f_D passed
# CT_f_conn_D_An passed
# CT_f_conn_A_Ca passed
# CT_n_D_adj_An failed - 48 is not the same as expected 49
# CT_n_A_adj_Ca failed - 29 is not the same as expected 30
# Total time to calculate graph: 0.1923058032989502 second(s)
# Total time to calculate descriptors: 0.3776967525482178 second(s)
# Peak memory usage for descriptor calculation: 30016 bytes
# {'STAT_n': 3780, 'STAT_e': 613, 'STAT_n_D': 2035, 'STAT_n_A': 1745, 'STAT_CC_D': 7, 'STAT_CC_A': 1, 'STAT_CC_D_An': 3, 'STAT_CC_A_Ca': 1, 'ABS_f_D': 0.53836, 'CT_f_conn_D_An': 0.287961, 'CT_f_conn_A_Ca': 1.0, 'CT_n_D_adj_An': 48, 'CT_n_A_adj_Ca': 29, 'time': 0.3776967525482178, 'mem': 30016}
#
# data_0.615_4.0_000160 Results
# STAT_n passed
# STAT_e passed
# STAT_n_D passed
# STAT_n_A passed
# STAT_CC_D passed
# STAT_CC_A passed
# STAT_CC_D_An passed
# STAT_CC_A_Ca passed
# ABS_f_D passed
# CT_f_conn_D_An passed
# CT_f_conn_A_Ca passed
# CT_n_D_adj_An passed
# CT_n_A_adj_Ca passed
# Total time to calculate graph: 9.578058958053589 second(s)
# Total time to calculate descriptors: 3.8526031970977783 second(s)
# Peak memory usage for descriptor calculation: 322995 bytes
# {'STAT_n': 40501, 'STAT_e': 3523, 'STAT_n_D': 16223, 'STAT_n_A': 24278, 'STAT_CC_D': 43, 'STAT_CC_A': 1, 'STAT_CC_D_An': 7, 'STAT_CC_A_Ca': 1, 'ABS_f_D': 0.400558, 'CT_f_conn_D_An': 0.134192, 'CT_f_conn_A_Ca': 1.0, 'CT_n_D_adj_An': 147, 'CT_n_A_adj_Ca': 197, 'time': 3.8526031970977783, 'mem': 322995}
#
# morphology_resize_1x Results
# STAT_n passed
# STAT_e passed
# STAT_n_D passed
# STAT_n_A passed
# STAT_CC_D passed
# STAT_CC_A passed
# STAT_CC_D_An passed
# STAT_CC_A_Ca passed
# ABS_f_D passed
# CT_f_conn_D_An passed
# CT_f_conn_A_Ca passed
# CT_n_D_adj_An failed - 190 is not the same as expected 191
# CT_n_A_adj_Ca failed - 109 is not the same as expected 110
# Total time to calculate graph: 11.99768328666687 second(s)
# Total time to calculate descriptors: 5.801064968109131 second(s)
# Peak memory usage for descriptor calculation: 488999 bytes
# {'STAT_n': 61258, 'STAT_e': 2472, 'STAT_n_D': 33125, 'STAT_n_A': 28133, 'STAT_CC_D': 7, 'STAT_CC_A': 1, 'STAT_CC_D_An': 3, 'STAT_CC_A_Ca': 1, 'ABS_f_D': 0.540746, 'CT_f_conn_D_An': 0.284196, 'CT_f_conn_A_Ca': 1.0, 'CT_n_D_adj_An': 190, 'CT_n_A_adj_Ca': 109, 'time': 5.801064968109131, 'mem': 488999}
#
# testFile-10-2D Results
# STAT_n passed
# STAT_e passed
# STAT_n_D passed
# STAT_n_A passed
# STAT_CC_D passed
# STAT_CC_A passed
# STAT_CC_D_An passed
# STAT_CC_A_Ca passed
# ABS_f_D passed
# CT_f_conn_D_An passed
# CT_f_conn_A_Ca passed
# CT_n_D_adj_An failed - 0 is not the same as expected 1
# CT_n_A_adj_Ca failed - 0 is not the same as expected 1
# Total time to calculate graph: 0.002444028854370117 second(s)
# Total time to calculate descriptors: 0.008190155029296875 second(s)
# Peak memory usage for descriptor calculation: 405 bytes
# {'STAT_n': 100, 'STAT_e': 10, 'STAT_n_D': 50, 'STAT_n_A': 50, 'STAT_CC_D': 1, 'STAT_CC_A': 1, 'STAT_CC_D_An': 0, 'STAT_CC_A_Ca': 0, 'ABS_f_D': 0.5, 'CT_f_conn_D_An': 0.0, 'CT_f_conn_A_Ca': 0.0, 'CT_n_D_adj_An': 0, 'CT_n_A_adj_Ca': 0, 'time': 0.008190155029296875, 'mem': 405}
#
# data_0.5_2.6_000160 Results
# STAT_n passed
# STAT_e passed
# STAT_n_D passed
# STAT_n_A passed
# STAT_CC_D passed
# STAT_CC_A passed
# STAT_CC_D_An passed
# STAT_CC_A_Ca passed
# ABS_f_D passed
# CT_f_conn_D_An passed
# CT_f_conn_A_Ca passed
# CT_n_D_adj_An passed
# CT_n_A_adj_Ca passed
# Total time to calculate graph: 5.847218036651611 second(s)
# Total time to calculate descriptors: 3.8063011169433594 second(s)
# Peak memory usage for descriptor calculation: 322853 bytes
# {'STAT_n': 40501, 'STAT_e': 2022, 'STAT_n_D': 20193, 'STAT_n_A': 20308, 'STAT_CC_D': 8, 'STAT_CC_A': 6, 'STAT_CC_D_An': 4, 'STAT_CC_A_Ca': 3, 'ABS_f_D': 0.49858, 'CT_f_conn_D_An': 0.81038, 'CT_f_conn_A_Ca': 0.724838, 'CT_n_D_adj_An': 186, 'CT_n_A_adj_Ca': 233, 'time': 3.8063011169433594, 'mem': 322853}
#
# data_4_3 Results
# STAT_n passed
# STAT_e passed
# STAT_n_D passed
# STAT_n_A passed
# STAT_CC_D passed
# STAT_CC_A passed
# STAT_CC_D_An passed
# STAT_CC_A_Ca passed
# ABS_f_D passed
# CT_f_conn_D_An passed
# CT_f_conn_A_Ca passed
# CT_n_D_adj_An passed
# CT_n_A_adj_Ca passed
# Total time to calculate graph: 0.0012600421905517578 second(s)
# Total time to calculate descriptors: 0.001500844955444336 second(s)
# Peak memory usage for descriptor calculation: 389 bytes
# {'STAT_n': 12, 'STAT_e': 8, 'STAT_n_D': 6, 'STAT_n_A': 6, 'STAT_CC_D': 1, 'STAT_CC_A': 1, 'STAT_CC_D_An': 1, 'STAT_CC_A_Ca': 1, 'ABS_f_D': 0.5, 'CT_f_conn_D_An': 1.0, 'CT_f_conn_A_Ca': 1.0, 'CT_n_D_adj_An': 2, 'CT_n_A_adj_Ca': 2, 'time': 0.001500844955444336, 'mem': 389}
#
# data_5x4x3 Results
# STAT_n passed
# STAT_e passed
# STAT_n_D passed
# STAT_n_A passed
# STAT_CC_D passed
# STAT_CC_A passed
# STAT_CC_D_An passed
# STAT_CC_A_Ca passed
# ABS_f_D passed
# CT_f_conn_D_An passed
# CT_f_conn_A_Ca passed
# CT_n_D_adj_An failed - 9 is not the same as expected 13
# CT_n_A_adj_Ca failed - 6 is not the same as expected 9
# Total time to calculate graph: 0.0013549327850341797 second(s)
# Total time to calculate descriptors: 0.010004997253417969 second(s)
# Peak memory usage for descriptor calculation: 389 bytes
# {'STAT_n': 60, 'STAT_e': 48, 'STAT_n_D': 36, 'STAT_n_A': 24, 'STAT_CC_D': 2, 'STAT_CC_A': 2, 'STAT_CC_D_An': 2, 'STAT_CC_A_Ca': 2, 'ABS_f_D': 0.6, 'CT_f_conn_D_An': 1.0, 'CT_f_conn_A_Ca': 1.0, 'CT_n_D_adj_An': 9, 'CT_n_A_adj_Ca': 6, 'time': 0.010004997253417969, 'mem': 389}
#
# testFile-50-2D Results
# STAT_n passed
# STAT_e passed
# STAT_n_D passed
# STAT_n_A passed
# STAT_CC_D passed
# STAT_CC_A passed
# STAT_CC_D_An passed
# STAT_CC_A_Ca passed
# ABS_f_D passed
# CT_f_conn_D_An passed
# CT_f_conn_A_Ca passed
# CT_n_D_adj_An failed - 0 is not the same as expected 1
# CT_n_A_adj_Ca failed - 0 is not the same as expected 1
# Total time to calculate graph: 0.03680682182312012 second(s)
# Total time to calculate descriptors: 0.2308807373046875 second(s)
# Peak memory usage for descriptor calculation: 17931 bytes
# {'STAT_n': 2500, 'STAT_e': 50, 'STAT_n_D': 1250, 'STAT_n_A': 1250, 'STAT_CC_D': 1, 'STAT_CC_A': 1, 'STAT_CC_D_An': 0, 'STAT_CC_A_Ca': 0, 'ABS_f_D': 0.5, 'CT_f_conn_D_An': 0.0, 'CT_f_conn_A_Ca': 0.0, 'CT_n_D_adj_An': 0, 'CT_n_A_adj_Ca': 0, 'time': 0.2308807373046875, 'mem': 17931}
#
# testFile-1000-2D Results
# STAT_n passed
# STAT_e passed
# STAT_n_D passed
# STAT_n_A passed
# STAT_CC_D passed
# STAT_CC_A passed
# STAT_CC_D_An passed
# STAT_CC_A_Ca passed
# ABS_f_D passed
# CT_f_conn_D_An passed
# CT_f_conn_A_Ca passed
# CT_n_D_adj_An failed - 0 is not the same as expected 1
# CT_n_A_adj_Ca failed - 0 is not the same as expected 1
# Total time to calculate graph: 193.62910890579224 second(s)
# Total time to calculate descriptors: 90.24094414710999 second(s)
# Peak memory usage for descriptor calculation: 7999302 bytes
# {'STAT_n': 1000000, 'STAT_e': 1000, 'STAT_n_D': 500000, 'STAT_n_A': 500000, 'STAT_CC_D': 1, 'STAT_CC_A': 1, 'STAT_CC_D_An': 0, 'STAT_CC_A_Ca': 0, 'ABS_f_D': 0.5, 'CT_f_conn_D_An': 0.0, 'CT_f_conn_A_Ca': 0.0, 'CT_n_D_adj_An': 0, 'CT_n_A_adj_Ca': 0, 'time': 90.24094414710999, 'mem': 7999302}
#
# morphology_resize_2x Results
# STAT_n passed
# STAT_e passed
# STAT_n_D passed
# STAT_n_A passed
# STAT_CC_D passed
# STAT_CC_A passed
# STAT_CC_D_An passed
# STAT_CC_A_Ca passed
# ABS_f_D passed
# CT_f_conn_D_An passed
# CT_f_conn_A_Ca passed
# CT_n_D_adj_An failed - 380 is not the same as expected 381
# CT_n_A_adj_Ca failed - 218 is not the same as expected 219
# Total time to calculate graph: 107.80305886268616 second(s)
# Total time to calculate descriptors: 22.99318027496338 second(s)
# Peak memory usage for descriptor calculation: 1959583 bytes
# {'STAT_n': 245032, 'STAT_e': 4944, 'STAT_n_D': 132500, 'STAT_n_A': 112532, 'STAT_CC_D': 7, 'STAT_CC_A': 1, 'STAT_CC_D_An': 3, 'STAT_CC_A_Ca': 1, 'ABS_f_D': 0.540746, 'CT_f_conn_D_An': 0.284196, 'CT_f_conn_A_Ca': 1.0, 'CT_n_D_adj_An': 380, 'CT_n_A_adj_Ca': 218, 'time': 22.99318027496338, 'mem': 1959583}
#
# testFile-500-2D Results
# STAT_n passed
# STAT_e passed
# STAT_n_D passed
# STAT_n_A passed
# STAT_CC_D passed
# STAT_CC_A passed
# STAT_CC_D_An passed
# STAT_CC_A_Ca passed
# ABS_f_D passed
# CT_f_conn_D_An passed
# CT_f_conn_A_Ca passed
# CT_n_D_adj_An failed - 0 is not the same as expected 1
# CT_n_A_adj_Ca failed - 0 is not the same as expected 1
# Total time to calculate graph: 26.47594904899597 second(s)
# Total time to calculate descriptors: 22.061394929885864 second(s)
# Peak memory usage for descriptor calculation: 1998911 bytes
# {'STAT_n': 250000, 'STAT_e': 500, 'STAT_n_D': 125000, 'STAT_n_A': 125000, 'STAT_CC_D': 1, 'STAT_CC_A': 1, 'STAT_CC_D_An': 0, 'STAT_CC_A_Ca': 0, 'ABS_f_D': 0.5, 'CT_f_conn_D_An': 0.0, 'CT_f_conn_A_Ca': 0.0, 'CT_n_D_adj_An': 0, 'CT_n_A_adj_Ca': 0, 'time': 22.061394929885864, 'mem': 1998911}
#
# data_4_3_2 Results
# STAT_n passed
# STAT_e failed - 22 is not the same as expected 24
# STAT_n_D passed
# STAT_n_A passed
# STAT_CC_D passed
# STAT_CC_A passed
# STAT_CC_D_An passed
# STAT_CC_A_Ca passed
# ABS_f_D passed
# CT_f_conn_D_An passed
# CT_f_conn_A_Ca passed
# CT_n_D_adj_An failed - 4 is not the same as expected 7
# CT_n_A_adj_Ca failed - 4 is not the same as expected 7
# Total time to calculate graph: 0.004148960113525391 second(s)
# Total time to calculate descriptors: 0.004012107849121094 second(s)
# Peak memory usage for descriptor calculation: 389 bytes
# {'STAT_n': 24, 'STAT_e': 22, 'STAT_n_D': 12, 'STAT_n_A': 12, 'STAT_CC_D': 1, 'STAT_CC_A': 1, 'STAT_CC_D_An': 1, 'STAT_CC_A_Ca': 1, 'ABS_f_D': 0.5, 'CT_f_conn_D_An': 1.0, 'CT_f_conn_A_Ca': 1.0, 'CT_n_D_adj_An': 4, 'CT_n_A_adj_Ca': 4, 'time': 0.004012107849121094, 'mem': 389}
#
# morphology_resize_4x Results
# STAT_n passed
# STAT_e passed
# STAT_n_D passed
# STAT_n_A passed
# STAT_CC_D passed
# STAT_CC_A passed
# STAT_CC_D_An passed
# STAT_CC_A_Ca passed
# ABS_f_D passed
# CT_f_conn_D_An passed
# CT_f_conn_A_Ca passed
# CT_n_D_adj_An failed - 760 is not the same as expected 761
# CT_n_A_adj_Ca failed - 436 is not the same as expected 437
# Total time to calculate graph: 850.3908479213715 second(s)
# Total time to calculate descriptors: 94.57439494132996 second(s)
# Peak memory usage for descriptor calculation: 7840319 bytes
# {'STAT_n': 980128, 'STAT_e': 9888, 'STAT_n_D': 530000, 'STAT_n_A': 450128, 'STAT_CC_D': 7, 'STAT_CC_A': 1, 'STAT_CC_D_An': 3, 'STAT_CC_A_Ca': 1, 'ABS_f_D': 0.540746, 'CT_f_conn_D_An': 0.284196, 'CT_f_conn_A_Ca': 1.0, 'CT_n_D_adj_An': 760, 'CT_n_A_adj_Ca': 436, 'time': 94.57439494132996, 'mem': 7840319}
#
# morphology_resize_0.5x Results
# STAT_n passed
# STAT_e passed
# STAT_n_D passed
# STAT_n_A passed
# STAT_CC_D passed
# STAT_CC_A passed
# STAT_CC_D_An passed
# STAT_CC_A_Ca passed
# ABS_f_D passed
# CT_f_conn_D_An passed
# CT_f_conn_A_Ca passed
# CT_n_D_adj_An failed - 94 is not the same as expected 95
# CT_n_A_adj_Ca failed - 54 is not the same as expected 55
# Total time to calculate graph: 1.6406002044677734 second(s)
# Total time to calculate descriptors: 1.4969491958618164 second(s)
# Peak memory usage for descriptor calculation: 121856 bytes
# {'STAT_n': 15260, 'STAT_e': 1226, 'STAT_n_D': 8226, 'STAT_n_A': 7034, 'STAT_CC_D': 7, 'STAT_CC_A': 1, 'STAT_CC_D_An': 3, 'STAT_CC_A_Ca': 1, 'ABS_f_D': 0.539056, 'CT_f_conn_D_An': 0.281668, 'CT_f_conn_A_Ca': 1.0, 'CT_n_D_adj_An': 94, 'CT_n_A_adj_Ca': 54, 'time': 1.4969491958618164, 'mem': 121856}

# %% [markdown]
# import withoutP_igraph_testing as ig
# import descriptors as ds
# import os
#
# current_dir = os.getcwd()
# data_path = f"{current_dir}/graspi_igraph/data/"
# descriptors_path = f"{current_dir}/graspi_igraph/descriptors/"
# test_files = [os.path.splitext(file)[0] for file in os.listdir(data_path)]
# epsilon=1e-5
# for test_file in test_files:
#     # g = ig.generateGraph(data_path + test_file + ".txt")
#     import time
#     graph_start = time.time()
#     g, is_2d= ig.generateGraphAdj(data_path + test_file + ".txt")
#     graph_end = time.time()
#     stats = ds.desciptors(g)
#     #ig.visual2D(g, 'graph')
#
#     print(f"{test_file} Results")
#
#     with open(descriptors_path + "descriptors." + test_file + ".log") as f:
#         for line in f:
#             stat = line.strip().split(" ")
#             try:
#                 # if stats.get(stat[0], -1) == int(stat[1]):
#                 if abs(stats.get(stat[0], -1) - float(stat[1])) < epsilon:
#                     print(f"{stat[0]} passed")
#                 elif stats.get(stat[0], -1) != -1 and stats.get(stat[0], -1) != int(stat[1]):
#                     print(f"{stat[0]} failed - {stats.get(stat[0])} is not the same as expected {stat[1]}")
#             except ValueError:
#                 if abs(stats.get(stat[0], -1) - float(stat[1])) < epsilon:
#                     print(f"{stat[0]} passed")
#                 elif stats.get(stat[0], -1) != -1 and stats.get(stat[0], -1) != float(stat[1]):
#                     print(f"{stat[0]} failed - {stats.get(stat[0])} is not the same as expected {stat[1]}")
#     time = stats["time"]
#     mem = stats["mem"]
#     graph_time = graph_end-graph_start
#     print(f"Total time to calculate graph: {graph_time} second(s)")
#     print(f"Total time to calculate descriptors: {time}second(s)")
#     print(f"Peak memory usage for descriptor calculation: {mem}bytes")
#     print(stats)
#     print("")

# %%
import combined_with as ig
import new_descriptors as ds
import os
import time

current_dir = os.getcwd()
data_path = f"{current_dir}/graspi_igraph/data/"
descriptors_path = f"{current_dir}/graspi_igraph/p1descriptors/"
test_files = [os.path.splitext(file)[0] for file in os.listdir(data_path)]
epsilon=1e-4
for test_file in test_files:
    # if 'morph' not in test_file:
    #     continue
    if '1x' not in test_file:
        continue
    # g = ig.generateGraph(data_path + test_file + ".txt")
    import time
    graph_start = time.time()
    g,is_2D, black_vertices, white_vertices, black_green, black_interface_red, white_interface_blue, dim, interface_edge_comp_paths, shortest_path_to_red, shortest_path_to_blue, CT_n_D_adj_An, CT_n_A_adj_Ca= ig.generateGraph(data_path + test_file + ".txt")
    graph_end = time.time()
    stats = ds.descriptors(g, test_file, black_vertices, white_vertices, black_green, black_interface_red, white_interface_blue, dim, interface_edge_comp_paths, shortest_path_to_red, shortest_path_to_blue, CT_n_D_adj_An, CT_n_A_adj_Ca)
    #ig.visual2D(g, 'graph')

    print(f"{test_file} Results")

    with open(descriptors_path + "p1descriptors." + test_file + ".log") as f:
        for line in f:
            stat = line.strip().split(" ")
            try:
                # if stats.get(stat[0], -1) == int(stat[1]):
                if abs(stats.get(stat[0], -1) - float(stat[1])) < epsilon:
                    print(f"{stat[0]} passed")
                elif stats.get(stat[0], -1) != -1 and stats.get(stat[0], -1) != int(stat[1]):
                    print(f"{stat[0]} failed - {stats.get(stat[0])} is not the same as expected {stat[1]}")
            except ValueError:
                if abs(stats.get(stat[0], -1) - float(stat[1])) < epsilon:
                    print(f"{stat[0]} passed")
                elif stats.get(stat[0], -1) != -1 and stats.get(stat[0], -1) != float(stat[1]):
                    print(f"{stat[0]} failed - {stats.get(stat[0])} is not the same as expected {stat[1]}")
    time = stats["time"]
    mem = stats["mem"]
    graph_time = graph_end-graph_start
    print(f"Total time to calculate graph: {graph_time} second(s)")
    print(f"Total time to calculate descriptors: {time} second(s)")
    print(f"Peak memory usage for descriptor calculation: {mem} bytes")
    print(stats)
    print("")
# Out:
# this is the number of edges 249695
# extra = 4944
# morphology_resize_1x Results
# STAT_n passed
# STAT_e passed
# STAT_n_D passed
# STAT_n_A passed
# STAT_CC_D passed
# STAT_CC_A passed
# STAT_CC_D_An passed
# STAT_CC_A_Ca passed
# ABS_f_D passed
# DISS_wf10_D failed - 0.3139972565253588 is not the same as expected 0.294456
# DISS_f10_D passed
# CT_f_e_conn passed
# CT_f_conn_D_An passed
# CT_f_conn_A_Ca passed
# CT_e_conn passed
# CT_e_D_An failed - 692 is not the same as expected 686
# CT_e_A_Ca failed - 2472 is not the same as expected 2488
# CT_f_D_tort1 failed - 0.21135094339622643 is not the same as expected 0.74368
# CT_f_A_tort1 passed
# CT_n_D_adj_An failed - 190 is not the same as expected 191
# CT_n_A_adj_Ca failed - 109 is not the same as expected 110
# Total time to calculate graph: 1.467778205871582 second(s)
# Total time to calculate descriptors: 20.67875027656555 second(s)
# Peak memory usage for descriptor calculation: 80320960 bytes
# {'STAT_n': 61258, 'STAT_e': 2472, 'STAT_n_D': 33125, 'STAT_n_A': 28133, 'STAT_CC_D': 7, 'STAT_CC_A': 1, 'STAT_CC_D_An': 3, 'STAT_CC_A_Ca': 1, 'ABS_f_D': 0.5407456985210095, 'DISS_f10_D': 0.5615094339622642, 'DISS_wf10_D': 0.3139972565253588, 'CT_f_e_conn': 0.27993527508090615, 'CT_f_conn_D_An': np.float64(0.284196), 'CT_f_conn_A_Ca': np.float64(1.0), 'CT_e_conn': 692, 'CT_e_D_An': 692, 'CT_e_A_Ca': 2472, 'CT_n_D_adj_An': 190, 'CT_n_A_adj_Ca': 109, 'CT_f_D_tort1': 0.21135094339622643, 'CT_f_A_tort1': 0.10418369885899122, 'time': 20.67875027656555, 'mem': 80320960}

# %%
import combined_without as ig
import new_descriptors as ds
import os
import time

current_dir = os.getcwd()
data_path = f"{current_dir}/graspi_igraph/data/"
descriptors_path = f"{current_dir}/graspi_igraph/descriptors/"
test_files = [os.path.splitext(file)[0] for file in os.listdir(data_path)]
epsilon=1e-4
for test_file in test_files:
    # if 'morph' not in test_file:
    #     continue
    if '1x' not in test_file:
        continue
    
    # g = ig.generateGraph(data_path + test_file + ".txt")
    import time
    graph_start = time.time()
    g,is_2D, black_vertices, white_vertices, black_green, black_interface_red, white_interface_blue, dim, interface_edge_comp_paths, shortest_path_to_red, shortest_path_to_blue, CT_n_D_adj_An, CT_n_A_adj_Ca= ig.generateGraph(data_path + test_file + ".txt")
    graph_end = time.time()
    stats = ds.descriptors(g, test_file, black_vertices, white_vertices, black_green, black_interface_red, white_interface_blue, dim, interface_edge_comp_paths, shortest_path_to_red, shortest_path_to_blue, CT_n_D_adj_An, CT_n_A_adj_Ca)
    #ig.visual2D(g, 'graph')

    print(f"{test_file} Results")

    with open(descriptors_path + "descriptors." + test_file + ".log") as f:
        for line in f:
            stat = line.strip().split(" ")
            try:
                # if stats.get(stat[0], -1) == int(stat[1]):
                if abs(stats.get(stat[0], -1) - float(stat[1])) < epsilon:
                    print(f"{stat[0]} passed")
                elif stats.get(stat[0], -1) != -1 and stats.get(stat[0], -1) != int(stat[1]):
                    print(f"{stat[0]} failed - {stats.get(stat[0])} is not the same as expected {stat[1]}")
            except ValueError:
                if abs(stats.get(stat[0], -1) - float(stat[1])) < epsilon:
                    print(f"{stat[0]} passed")
                elif stats.get(stat[0], -1) != -1 and stats.get(stat[0], -1) != float(stat[1]):
                    print(f"{stat[0]} failed - {stats.get(stat[0])} is not the same as expected {stat[1]}")
    time = stats["time"]
    mem = stats["mem"]
    graph_time = graph_end-graph_start
    print(f"Total time to calculate graph: {graph_time} second(s)")
    print(f"Total time to calculate descriptors: {time} second(s)")
    print(f"Peak memory usage for descriptor calculation: {mem} bytes")
    print(stats)
    print("")
# Out:
# this is the number of edges 248753
# extra = 4654
# morphology_resize_1x Results
# STAT_n passed
# STAT_e passed
# STAT_n_D passed
# STAT_n_A passed
# STAT_CC_D passed
# STAT_CC_A passed
# STAT_CC_D_An passed
# STAT_CC_A_Ca passed
# ABS_f_D passed
# DISS_wf10_D failed - 0.29921123681760825 is not the same as expected 0.278467
# DISS_f10_D passed
# CT_f_e_conn passed
# CT_f_conn_D_An passed
# CT_f_conn_A_Ca passed
# CT_e_conn passed
# CT_e_D_An failed - 666 is not the same as expected 660
# CT_e_A_Ca failed - 2327 is not the same as expected 2342
# CT_f_D_tort1 failed - 0.21135094339622643 is not the same as expected 0.74368
# CT_f_A_tort1 passed
# CT_n_D_adj_An failed - 190 is not the same as expected 191
# CT_n_A_adj_Ca failed - 109 is not the same as expected 110
# Total time to calculate graph: 1.4580299854278564 second(s)
# Total time to calculate descriptors: 20.84941005706787 second(s)
# Peak memory usage for descriptor calculation: 80070147 bytes
# {'STAT_n': 61258, 'STAT_e': 2327, 'STAT_n_D': 33125, 'STAT_n_A': 28133, 'STAT_CC_D': 10, 'STAT_CC_A': 2, 'STAT_CC_D_An': 4, 'STAT_CC_A_Ca': 2, 'ABS_f_D': 0.5407456985210095, 'DISS_f10_D': 0.5363622641509433, 'DISS_wf10_D': 0.29921123681760825, 'CT_f_e_conn': 0.2862054146970348, 'CT_f_conn_D_An': np.float64(0.284196), 'CT_f_conn_A_Ca': np.float64(1.0), 'CT_e_conn': 666, 'CT_e_D_An': 666, 'CT_e_A_Ca': 2327, 'CT_n_D_adj_An': 190, 'CT_n_A_adj_Ca': 109, 'CT_f_D_tort1': 0.21135094339622643, 'CT_f_A_tort1': 0.10418369885899122, 'time': 20.84941005706787, 'mem': 80070147}
