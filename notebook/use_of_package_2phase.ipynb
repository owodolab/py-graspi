# %% [markdown]
# The command line code pip install will install the py-graspi package which will download necessary python libraries needed for the functions within the package to work. In other hands, without this line of code not only will the functions not be avaliable to the user but even if you have a clone of the package it will ont run since the necessary libraries have not been installed. This line does both in one.

# %%
# !pip install py-graspi
# Out:
# Requirement already satisfied: py-graspi in /Users/laibahahmed/PycharmProjects/profilingpygraspi/.venv/lib/python3.11/site-packages (0.2.1.2)
# Requirement already satisfied: igraph in /Users/laibahahmed/PycharmProjects/profilingpygraspi/.venv/lib/python3.11/site-packages (from py-graspi) (0.11.6)
# Requirement already satisfied: matplotlib in /Users/laibahahmed/PycharmProjects/profilingpygraspi/.venv/lib/python3.11/site-packages (from py-graspi) (3.9.2)
# Requirement already satisfied: numpy in /Users/laibahahmed/PycharmProjects/profilingpygraspi/.venv/lib/python3.11/site-packages (from py-graspi) (2.1.1)
# Requirement already satisfied: contourpy in /Users/laibahahmed/PycharmProjects/profilingpygraspi/.venv/lib/python3.11/site-packages (from py-graspi) (1.3.0)
# Requirement already satisfied: cycler in /Users/laibahahmed/PycharmProjects/profilingpygraspi/.venv/lib/python3.11/site-packages (from py-graspi) (0.12.1)
# Requirement already satisfied: fonttools in /Users/laibahahmed/PycharmProjects/profilingpygraspi/.venv/lib/python3.11/site-packages (from py-graspi) (4.53.1)
# Requirement already satisfied: kiwisolver in /Users/laibahahmed/PycharmProjects/profilingpygraspi/.venv/lib/python3.11/site-packages (from py-graspi) (1.4.7)
# Requirement already satisfied: packaging in /Users/laibahahmed/PycharmProjects/profilingpygraspi/.venv/lib/python3.11/site-packages (from py-graspi) (24.1)
# Requirement already satisfied: pillow in /Users/laibahahmed/PycharmProjects/profilingpygraspi/.venv/lib/python3.11/site-packages (from py-graspi) (10.4.0)
# Requirement already satisfied: psutil in /Users/laibahahmed/PycharmProjects/profilingpygraspi/.venv/lib/python3.11/site-packages (from py-graspi) (6.0.0)
# Requirement already satisfied: pyparsing in /Users/laibahahmed/PycharmProjects/profilingpygraspi/.venv/lib/python3.11/site-packages (from py-graspi) (3.1.4)
# Requirement already satisfied: python-dateutil in /Users/laibahahmed/PycharmProjects/profilingpygraspi/.venv/lib/python3.11/site-packages (from py-graspi) (2.9.0.post0)
# Requirement already satisfied: six in /Users/laibahahmed/PycharmProjects/profilingpygraspi/.venv/lib/python3.11/site-packages (from py-graspi) (1.16.0)
# Requirement already satisfied: texttable in /Users/laibahahmed/PycharmProjects/profilingpygraspi/.venv/lib/python3.11/site-packages (from py-graspi) (1.7.0)
# Requirement already satisfied: fpdf in /Users/laibahahmed/PycharmProjects/profilingpygraspi/.venv/lib/python3.11/site-packages (from py-graspi) (1.7.2)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
#import py_graspi library
import py_graspi as ig

# %% [markdown]
# An example file is given and stored in the variable filename. This will be used in place of a command line argument since the functions need a .txt input file with proper formatting to generate a graph for the given file (Note: you can utilize your own properly formatted .txt file as long as the pathname of each file is correct)

# %%
#Below is the pathname of an image to use for an example

filename = "../data/2phase/2D-testFiles/testFile-4x3-2D.txt"

# %% [markdown]
# The generateGraphAdj(filename) function below is from the py-graspi package is used to create a graph for any proper formated .txt file. It returns a graph_data_class where the newly generated graph is now stored as well as some other graph related information, these other variables are used when calculating descriptors for the file. (Note the inclusion of "py_graspi." before the function name which is needed to signal that you are reaching into the package for this given function).

# %%
#This function will create a graph based on any given txt file input
graph_data = ig.generateGraphAdj(filename)

# %%
ig.visualize(graph_data.graph, graph_data.is_2D)

# %%
#This function will create a tuple holding in the name and value of all descriptors
dict_descriptors = ig.compute_descriptors(graph_data, filename)

# %% [markdown]
# We then create an example outputFile string variable which will have a .txt extension and will be used in this Notebook to copy the dictionary gotten from the descriptors() function into a .txt file.

# %%
#We will use the filename below to be the output txt file for the 
outputFile = "example_descriptors.txt"

# %% [markdown]
# This next line is a package function that writes the descriptors to a designated file path.

# %%
#Copy descriptor tuple into txt file
ig.descriptorsToTxt(dict_descriptors, outputFile)

# %% [markdown]
# Finally to make sure the descriptors were properly written to the file we will now open the same outputFile in READ mode now and print out its contents and make sure we have the correct dictionary.

# %%
#Output txt file, if error occurs this means txt file was not properly created
ig.readDescriptorsFromTxt(outputFile)
# Out:
# STAT_n 12.0
# STAT_e 7.0
# STAT_n_D 6.0
# STAT_n_A 6.0
# STAT_CC_D 2.0
# STAT_CC_A 1.0
# STAT_CC_D_An 2.0
# STAT_CC_A_Ca 1.0
# ABS_wf_D 0.4950414178426539
# ABS_f_D 0.5
# DISS_f10_D 1.0
# DISS_wf10_D 0.9383521687023219
# CT_f_e_conn 1.0
# CT_f_conn_D_An 1.0
# CT_f_conn_A_Ca 1.0
# CT_e_conn 7.0
# CT_e_D_An 6.0
# CT_e_A_Ca 6.0
# CT_n_D_adj_An 2.0
# CT_n_A_adj_Ca 2.0
# CT_f_D_tort1 1.0
# CT_f_A_tort1 0.8333333333333334
